# %% [markdown]
# # 数据科学之分进合击进阶分析策略
#
# *  本周主要内容：数据重塑（Reshape）与数据透视表（pivot, pivot_table）**系统**说明和实践
# *  上周主要内容：(1)新增变量丶(2)重塑丶(3)聚合的**初步**介绍和实践
# *  20春_Web数据分析_week05
# *  电子讲义设计者：廖汉腾, 许智超

# %%
# %%html
# <style>
# /* 本电子讲义使用之CSS */
# div.code_cell {
#     background-color: #e5f1fe;
# }
# div.cell.selected {
#     background-color: #effee2;
#     font-size: 2rem;
#     line-height: 2.4rem;
# }
# div.cell.selected .rendered_html table {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html pre code {
#     background-color: #C4E4ff;
#     padding: 2px 25px;
# }
# .rendered_html pre {
#     background-color: #99c9ff;
# }
# div.code_cell .CodeMirror {
#     font-size: 2rem !important;
#     line-height: 3.6rem !important;
# }
# .rendered_html img, .rendered_html svg {
#     max-width: 60%;
#     height: auto;
#     float: right;
# }
#
# .rendered_html img[src*="#full"], .rendered_html svg[src*="#full"] {
#     max-width: 100%;
#     height: auto;
#     float: none;
# }
#
# .rendered_html img[src*="#thumbnail"], .rendered_html svg[src*="#thumbnail"] {
#     max-width: 15%;
#     height: auto;
# }
# .rendered_html img[src*="#thumbnailauto"], .rendered_html svg[src*="#thumbnail"] {
#     max-width: auto;
#     height: auto;
# }
#
# /* Gradient transparent - color - transparent */
# hr {
#     border: 0;
#     border-bottom: 1px dashed #ccc;
# }
# .emoticon{
#     font-size: 5rem;
#     line-height: 4.4rem;
#     text-align: center;
#     vertical-align: middle;
# }
# .bg-reshape {
#     width: 550px;
#     height: 205px;
#     background: url('../20春_pandas_CheatSheet.svg') -205px -110px;
#     float: left;
# }
# .break {
#                    page-break-after: right;
#                    width:100%;
#                    clear:both;
# }
# </style>
# Out:
# <style>
# /* 本电子讲义使用之CSS */
# div.code_cell {
#     background-color: #e5f1fe;
# }
# div.cell.selected {
#     background-color: #effee2;
#     font-size: 2rem;
#     line-height: 2.4rem;
# }
# div.cell.selected .rendered_html table {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html pre code {
#     background-color: #C4E4ff;
#     padding: 2px 25px;
# }
# .rendered_html pre {
#     background-color: #99c9ff;
# }
# div.code_cell .CodeMirror {
#     font-size: 2rem !important;
#     line-height: 3.6rem !important;
# }
# .rendered_html img, .rendered_html svg {
#     max-width: 60%;
#     height: auto;
#     float: right;
# }
#
# .rendered_html img[src*="#full"], .rendered_html svg[src*="#full"] {
#     max-width: 100%;
#     height: auto;
#     float: none;
# }
#
# .rendered_html img[src*="#thumbnail"], .rendered_html svg[src*="#thumbnail"] {
#     max-width: 15%;
#     height: auto;
# }
# .rendered_html img[src*="#thumbnailauto"], .rendered_html svg[src*="#thumbnail"] {
#     max-width: auto;
#     height: auto;
# }
#
# /* Gradient transparent - color - transparent */
# hr {
#     border: 0;
#     border-bottom: 1px dashed #ccc;
# }
# .emoticon{
#     font-size: 5rem;
#     line-height: 4.4rem;
#     text-align: center;
#     vertical-align: middle;
# }
# .bg-reshape {
#     width: 550px;
#     height: 205px;
#     background: url('../20春_pandas_CheatSheet.svg') -205px -110px;
#     float: left;
# }
# .break {
#                    page-break-after: right;
#                    width:100%;
#                    clear:both;
# }
# </style>

# %% [markdown]
# ##  介绍
#
# ### 上周主要内容：
# 1. 新增变量
#   * 用str字符串方法处理文本数据
# 2. 重塑
#   * drop, split, stack
# 3. 聚合
#   * merge
#
#
# ### 本电子讲义说明
#
# 本电子讲义为一系列课程的主要教材
# *  课程：20春_数据分析pandas （中山大学南方学院）
# *  设计者：廖汉腾, 许智超
# * 参考来源: [官方英文新手教程](https://pandas.pydata.org/pandas-docs/version/1.0.2/getting_started/index.html#getting-started)
#
# -----
#
# 课堂教学方式：
# * 分段式以英文新手教程的内容做示范及说明
# * 课堂上以实际中文数据做操练，每段约10-15分钟
# * 抽学生联mic自播说明难点及成果点，教师总结
#
# -----
#
# 课后实践方式：
# * 学生fork教师提供的代码，做以下实践
# * (必做)一项为此代码的实践，学生需要对ipynb文档中的说明(含markdown及图片)及代码进行演化改进，可以是注解说明，可以是调整参数实验，可以是额外方法实践，可以是以上的组合，学生
# * (选做)一项为此代码的延伸实践，学生对ipynb文档中的一部分或全部进行演化，变成另一个独立项目，说好或做好一件事

# %%
import pandas as pd

# %% [markdown]
# ## 本周内容纲要
# <div class="bg-reshape"></div>
#
# <div class="break"></div>
# <div class="break"></div>
#
#
# ### 本周主要内容：
#
# 以***独角兽数据***案例进行数据框数据重塑与数据透视表**系统说明和实践**：
# ![](https://support.content.office.net/en-us/media/095beeee-8781-4b14-be42-9b05e9aff8d3.png#thumbnailauto)
#
# 1. 数据重塑（Reshape）：
#   1. 对表格行进行排序（sort_values）
#   2. 长到宽表格式（pivot）
# 2. 数据透视表（pivot, pivot_table）
#   1. 对表格行进行排序（sort_values）
#   2. 长到宽表格式（pivot）
# 3. 比较数据透视表（pivot, pivot_table）
#   1. 和Excel相比
#   2. 和gropby相比
#
#
#
#
# -----
#
#
# ## 视觉化纲要
#
# -----
#
# ### 知识点
#
# ![](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/reshaping_pivot.png)
# 本周知识点主要为**在二维项度**上，以"类别"分进，以"数量"合击，内容包括以下：
#
# * 数据科学之分进合击**进阶**分析策略
#   * 什麽是pivot, pivot_table, cross_tab数据透序表
#   * 这为什麽对"出报表"很重要？
# * **复习**分进合击操演的心法及剑法学习
#   * 区分变量性质/数据型态 (variable types / data types)
#   * 分进多为"类别"，可以是定类或定序
#   * 合击常为"数量"，可以是定距或定比
# * 二维项度的设定决定及规划
#   * 使用nunique预判生成较宽表格的大小
#   * 多层次下的较复杂排序
#   * 数据框之"长"vs."宽"的使用差异
# -----
#
# ### 实践
#
# 以数个"类别"分进，再以"数量"合击初步实践2019胡润全球独角兽榜数据。本周实践内容共分5段：
#
# 1. 数据框出交叉报表
# 2. 数据框排序（sorted_values）
# 3. pivot说明
# 4. pivot_table说明
# 5. 数据感**进阶**：从聚合到解聚的操作感走向二维
#
# <div class="emoticon">😃😄😁</div>
#
# -----

# %% [markdown]
# # 数据框出交叉报表
#
# 数据科学之分进合击进阶分析策略，在本周会靠数据重塑（Reshape）与数据透视表（pivot, pivot_table）更上一层楼
#
# * [參考1](https://pandas.pydata.org/pandas-docs/version/1.0.2/getting_started/intro_tutorials/07_reshape_table_layout.html#min-tut-07-reshape)
# * [參考2](https://pandas.pydata.org/pandas-docs/version/1.0.2/user_guide/reshaping.html#reshaping)
#
#
# ## 初阶A-0：分进合击

# %%
# A-0 採用初阶分进合击分析策略 groupby ... agg
df = pd.read_csv ("20春_pandas_week02_hurun_unicorn.tsv", encoding = "utf8", sep="\t")
# df.info() # 注意看Dtype! 
分进合击初阶 = df.groupby(by= ["国家", "成立年份"]) \
                .agg({"估值（亿人民币）":"sum"}) 
分进合击初阶
# Out:
#           估值（亿人民币）
# 国家  成立年份
# 中国  2000       170
#     2001       170
#     2002       200
#     2003       200
#     2004       100
# ...            ...
# 韩国  2005        70
#     2007       350
#     2010       670
#     2011       270
# 马耳他 2017       150
#
# [100 rows x 1 columns]

# %% [markdown]
# 注意上表是有100列，1行数据
#
# 若想要把成立年份变量往行变量放呢？
#
# ## 迸阶A-1：分进合击pivot
#
# ![](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/reshaping_pivot.png)

# %%
# A-1 採用进阶分进合击分析策略 groupby ... agg  ... pivot
分进合击迸阶pv = df.groupby(by= ["国家","成立年份"]) \
                  .agg({"估值（亿人民币）":"sum"}) \
                  .reset_index() \
                  .set_index(["国家"]) \
                  .pivot(columns="成立年份", values="估值（亿人民币）")
print (分进合击迸阶pv.shape)
分进合击迸阶pv
# Out:
# (24, 20)
# 成立年份    2000   2001    2002   2003    2004   2005    2006    2007    2008  \
# 国家
# 中国     170.0  170.0   200.0  200.0   100.0  300.0  2380.0  1280.0   710.0
# 以色列      NaN    NaN   150.0    NaN     NaN    NaN     NaN     NaN     NaN
# 卢森堡      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 印度     150.0    NaN     NaN    NaN   150.0    NaN     NaN    70.0   840.0
# 印度尼西亚    NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 哥伦比亚     NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 巴西       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 德国     150.0    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 新加坡      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 日本       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 法国       NaN    NaN     NaN    NaN     NaN    NaN   220.0     NaN     NaN
# 澳大利亚     NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 爱尔兰    150.0    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 爱沙尼亚     NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 瑞典       NaN    NaN     NaN    NaN     NaN  300.0     NaN     NaN     NaN
# 瑞士       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 美国     210.0  210.0  6270.0  420.0  1550.0  840.0   810.0  2650.0  4570.0
# 芬兰       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 英国       NaN    NaN     NaN    NaN   350.0  150.0     NaN     NaN     NaN
# 菲律宾      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 西班牙      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 阿根廷      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 韩国       NaN    NaN     NaN    NaN     NaN   70.0     NaN   350.0     NaN
# 马耳他      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
#
# 成立年份     2009    2010    2011     2012    2013     2014    2015    2016  \
# 国家
# 中国      950.0  1590.0  6570.0  11330.0  5340.0  16150.0  3960.0  1300.0
# 以色列       NaN   210.0   150.0    150.0    70.0      NaN     NaN     NaN
# 卢森堡       NaN     NaN     NaN      NaN     NaN     70.0     NaN     NaN
# 印度        NaN  1300.0   440.0    140.0   350.0    270.0     NaN    70.0
# 印度尼西亚   500.0   700.0    70.0    300.0     NaN      NaN     NaN     NaN
# 哥伦比亚      NaN     NaN     NaN      NaN     NaN      NaN     NaN    70.0
# 巴西        NaN     NaN    70.0     70.0   370.0      NaN     NaN     NaN
# 德国       70.0     NaN   150.0    370.0   200.0     70.0     NaN     NaN
# 新加坡       NaN     NaN     NaN   1350.0     NaN      NaN     NaN     NaN
# 日本        NaN     NaN     NaN      NaN     NaN    220.0     NaN     NaN
# 法国        NaN     NaN     NaN      NaN    70.0      NaN     NaN    70.0
# 澳大利亚      NaN     NaN     NaN    200.0     NaN      NaN     NaN     NaN
# 爱尔兰       NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 爱沙尼亚      NaN     NaN     NaN      NaN    70.0      NaN     NaN     NaN
# 瑞典        NaN     NaN     NaN      NaN     NaN      NaN     NaN   150.0
# 瑞士        NaN     NaN     NaN     70.0     NaN    500.0   150.0     NaN
# 美国     2090.0  6150.0  2620.0   4670.0  3840.0   2220.0  5980.0  1690.0
# 芬兰        NaN     NaN     NaN      NaN     NaN      NaN     NaN    70.0
# 英国       70.0     NaN   550.0    450.0   350.0      NaN   350.0   150.0
# 菲律宾       NaN     NaN     NaN      NaN     NaN      NaN    70.0     NaN
# 西班牙       NaN     NaN    70.0      NaN     NaN      NaN     NaN     NaN
# 阿根廷       NaN     NaN     NaN      NaN    70.0      NaN     NaN     NaN
# 韩国        NaN   670.0   270.0      NaN     NaN      NaN     NaN     NaN
# 马耳他       NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
#
# 成立年份    2017    2018   2019
# 国家
# 中国     810.0  1090.0  100.0
# 以色列      NaN     NaN    NaN
# 卢森堡      NaN     NaN    NaN
# 印度      70.0     NaN    NaN
# 印度尼西亚    NaN     NaN    NaN
# 哥伦比亚     NaN     NaN    NaN
# 巴西       NaN     NaN    NaN
# 德国       NaN     NaN    NaN
# 新加坡      NaN     NaN    NaN
# 日本       NaN     NaN    NaN
# 法国       NaN     NaN    NaN
# 澳大利亚     NaN     NaN    NaN
# 爱尔兰      NaN     NaN    NaN
# 爱沙尼亚     NaN     NaN    NaN
# 瑞典       NaN     NaN    NaN
# 瑞士       NaN     NaN    NaN
# 美国     870.0     NaN   70.0
# 芬兰       NaN     NaN    NaN
# 英国       NaN     NaN    NaN
# 菲律宾      NaN     NaN    NaN
# 西班牙      NaN     NaN    NaN
# 阿根廷      NaN     NaN    NaN
# 韩国       NaN     NaN    NaN
# 马耳他    150.0     NaN    NaN

# %% [markdown]
# 注意上表是有24行20列数据，
#
# 成功的成立年份变量往行变量放，不过因有缺数据，20*24 > 100
#
# ## 迸阶A-2：分进合击pivot_table

# %% [markdown]
# 分类有index；值有values

# %%
# A-3 採用分进合击初阶分析策略  pivot_table
分进合击迸阶 = df.pivot_table(index= "国家", columns="成立年份",  \
                 values="估值（亿人民币）", aggfunc="sum") 
print (分进合击迸阶.shape)
分进合击迸阶
# Out:
# (24, 20)
# 成立年份    2000   2001    2002   2003    2004   2005    2006    2007    2008  \
# 国家
# 中国     170.0  170.0   200.0  200.0   100.0  300.0  2380.0  1280.0   710.0
# 以色列      NaN    NaN   150.0    NaN     NaN    NaN     NaN     NaN     NaN
# 卢森堡      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 印度     150.0    NaN     NaN    NaN   150.0    NaN     NaN    70.0   840.0
# 印度尼西亚    NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 哥伦比亚     NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 巴西       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 德国     150.0    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 新加坡      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 日本       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 法国       NaN    NaN     NaN    NaN     NaN    NaN   220.0     NaN     NaN
# 澳大利亚     NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 爱尔兰    150.0    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 爱沙尼亚     NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 瑞典       NaN    NaN     NaN    NaN     NaN  300.0     NaN     NaN     NaN
# 瑞士       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 美国     210.0  210.0  6270.0  420.0  1550.0  840.0   810.0  2650.0  4570.0
# 芬兰       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 英国       NaN    NaN     NaN    NaN   350.0  150.0     NaN     NaN     NaN
# 菲律宾      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 西班牙      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 阿根廷      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 韩国       NaN    NaN     NaN    NaN     NaN   70.0     NaN   350.0     NaN
# 马耳他      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
#
# 成立年份     2009    2010    2011     2012    2013     2014    2015    2016  \
# 国家
# 中国      950.0  1590.0  6570.0  11330.0  5340.0  16150.0  3960.0  1300.0
# 以色列       NaN   210.0   150.0    150.0    70.0      NaN     NaN     NaN
# 卢森堡       NaN     NaN     NaN      NaN     NaN     70.0     NaN     NaN
# 印度        NaN  1300.0   440.0    140.0   350.0    270.0     NaN    70.0
# 印度尼西亚   500.0   700.0    70.0    300.0     NaN      NaN     NaN     NaN
# 哥伦比亚      NaN     NaN     NaN      NaN     NaN      NaN     NaN    70.0
# 巴西        NaN     NaN    70.0     70.0   370.0      NaN     NaN     NaN
# 德国       70.0     NaN   150.0    370.0   200.0     70.0     NaN     NaN
# 新加坡       NaN     NaN     NaN   1350.0     NaN      NaN     NaN     NaN
# 日本        NaN     NaN     NaN      NaN     NaN    220.0     NaN     NaN
# 法国        NaN     NaN     NaN      NaN    70.0      NaN     NaN    70.0
# 澳大利亚      NaN     NaN     NaN    200.0     NaN      NaN     NaN     NaN
# 爱尔兰       NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 爱沙尼亚      NaN     NaN     NaN      NaN    70.0      NaN     NaN     NaN
# 瑞典        NaN     NaN     NaN      NaN     NaN      NaN     NaN   150.0
# 瑞士        NaN     NaN     NaN     70.0     NaN    500.0   150.0     NaN
# 美国     2090.0  6150.0  2620.0   4670.0  3840.0   2220.0  5980.0  1690.0
# 芬兰        NaN     NaN     NaN      NaN     NaN      NaN     NaN    70.0
# 英国       70.0     NaN   550.0    450.0   350.0      NaN   350.0   150.0
# 菲律宾       NaN     NaN     NaN      NaN     NaN      NaN    70.0     NaN
# 西班牙       NaN     NaN    70.0      NaN     NaN      NaN     NaN     NaN
# 阿根廷       NaN     NaN     NaN      NaN    70.0      NaN     NaN     NaN
# 韩国        NaN   670.0   270.0      NaN     NaN      NaN     NaN     NaN
# 马耳他       NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
#
# 成立年份    2017    2018   2019
# 国家
# 中国     810.0  1090.0  100.0
# 以色列      NaN     NaN    NaN
# 卢森堡      NaN     NaN    NaN
# 印度      70.0     NaN    NaN
# 印度尼西亚    NaN     NaN    NaN
# 哥伦比亚     NaN     NaN    NaN
# 巴西       NaN     NaN    NaN
# 德国       NaN     NaN    NaN
# 新加坡      NaN     NaN    NaN
# 日本       NaN     NaN    NaN
# 法国       NaN     NaN    NaN
# 澳大利亚     NaN     NaN    NaN
# 爱尔兰      NaN     NaN    NaN
# 爱沙尼亚     NaN     NaN    NaN
# 瑞典       NaN     NaN    NaN
# 瑞士       NaN     NaN    NaN
# 美国     870.0     NaN   70.0
# 芬兰       NaN     NaN    NaN
# 英国       NaN     NaN    NaN
# 菲律宾      NaN     NaN    NaN
# 西班牙      NaN     NaN    NaN
# 阿根廷      NaN     NaN    NaN
# 韩国       NaN     NaN    NaN
# 马耳他    150.0     NaN    NaN

# %% [markdown]
# ## 迸阶A-3：分进合击pivot_table 按总值排序

# %%
# A-3 pivot_table 按总值排序
排序 = 分进合击迸阶.sum(axis=1).sort_values(ascending=False).index
排序
排序_总值 = 分进合击迸阶.sum(axis=1).sort_values(ascending=False).values
排序_总值
分进合击迸阶_排序过 =  分进合击迸阶.loc[排序]
分进合击迸阶_排序过
分进合击迸阶_排序过['总值'] = 排序_总值
分进合击迸阶_排序过
# Out:
# 成立年份    2000   2001    2002   2003    2004   2005    2006    2007    2008  \
# 国家
# 中国     170.0  170.0   200.0  200.0   100.0  300.0  2380.0  1280.0   710.0
# 美国     210.0  210.0  6270.0  420.0  1550.0  840.0   810.0  2650.0  4570.0
# 印度     150.0    NaN     NaN    NaN   150.0    NaN     NaN    70.0   840.0
# 英国       NaN    NaN     NaN    NaN   350.0  150.0     NaN     NaN     NaN
# 印度尼西亚    NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 韩国       NaN    NaN     NaN    NaN     NaN   70.0     NaN   350.0     NaN
# 新加坡      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 德国     150.0    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 以色列      NaN    NaN   150.0    NaN     NaN    NaN     NaN     NaN     NaN
# 瑞士       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 巴西       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 瑞典       NaN    NaN     NaN    NaN     NaN  300.0     NaN     NaN     NaN
# 法国       NaN    NaN     NaN    NaN     NaN    NaN   220.0     NaN     NaN
# 日本       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 澳大利亚     NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 爱尔兰    150.0    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 马耳他      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 爱沙尼亚     NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 芬兰       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 哥伦比亚     NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 菲律宾      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 西班牙      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 卢森堡      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 阿根廷      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
#
# 成立年份     2009  ...    2011     2012    2013     2014    2015    2016   2017  \
# 国家             ...
# 中国      950.0  ...  6570.0  11330.0  5340.0  16150.0  3960.0  1300.0  810.0
# 美国     2090.0  ...  2620.0   4670.0  3840.0   2220.0  5980.0  1690.0  870.0
# 印度        NaN  ...   440.0    140.0   350.0    270.0     NaN    70.0   70.0
# 英国       70.0  ...   550.0    450.0   350.0      NaN   350.0   150.0    NaN
# 印度尼西亚   500.0  ...    70.0    300.0     NaN      NaN     NaN     NaN    NaN
# 韩国        NaN  ...   270.0      NaN     NaN      NaN     NaN     NaN    NaN
# 新加坡       NaN  ...     NaN   1350.0     NaN      NaN     NaN     NaN    NaN
# 德国       70.0  ...   150.0    370.0   200.0     70.0     NaN     NaN    NaN
# 以色列       NaN  ...   150.0    150.0    70.0      NaN     NaN     NaN    NaN
# 瑞士        NaN  ...     NaN     70.0     NaN    500.0   150.0     NaN    NaN
# 巴西        NaN  ...    70.0     70.0   370.0      NaN     NaN     NaN    NaN
# 瑞典        NaN  ...     NaN      NaN     NaN      NaN     NaN   150.0    NaN
# 法国        NaN  ...     NaN      NaN    70.0      NaN     NaN    70.0    NaN
# 日本        NaN  ...     NaN      NaN     NaN    220.0     NaN     NaN    NaN
# 澳大利亚      NaN  ...     NaN    200.0     NaN      NaN     NaN     NaN    NaN
# 爱尔兰       NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN    NaN
# 马耳他       NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN  150.0
# 爱沙尼亚      NaN  ...     NaN      NaN    70.0      NaN     NaN     NaN    NaN
# 芬兰        NaN  ...     NaN      NaN     NaN      NaN     NaN    70.0    NaN
# 哥伦比亚      NaN  ...     NaN      NaN     NaN      NaN     NaN    70.0    NaN
# 菲律宾       NaN  ...     NaN      NaN     NaN      NaN    70.0     NaN    NaN
# 西班牙       NaN  ...    70.0      NaN     NaN      NaN     NaN     NaN    NaN
# 卢森堡       NaN  ...     NaN      NaN     NaN     70.0     NaN     NaN    NaN
# 阿根廷       NaN  ...     NaN      NaN    70.0      NaN     NaN     NaN    NaN
#
# 成立年份     2018   2019       总值
# 国家
# 中国     1090.0  100.0  54700.0
# 美国        NaN   70.0  47730.0
# 印度        NaN    NaN   3850.0
# 英国        NaN    NaN   2420.0
# 印度尼西亚     NaN    NaN   1570.0
# 韩国        NaN    NaN   1360.0
# 新加坡       NaN    NaN   1350.0
# 德国        NaN    NaN   1010.0
# 以色列       NaN    NaN    730.0
# 瑞士        NaN    NaN    720.0
# 巴西        NaN    NaN    510.0
# 瑞典        NaN    NaN    450.0
# 法国        NaN    NaN    360.0
# 日本        NaN    NaN    220.0
# 澳大利亚      NaN    NaN    200.0
# 爱尔兰       NaN    NaN    150.0
# 马耳他       NaN    NaN    150.0
# 爱沙尼亚      NaN    NaN     70.0
# 芬兰        NaN    NaN     70.0
# 哥伦比亚      NaN    NaN     70.0
# 菲律宾       NaN    NaN     70.0
# 西班牙       NaN    NaN     70.0
# 卢森堡       NaN    NaN     70.0
# 阿根廷       NaN    NaN     70.0
#
# [24 rows x 21 columns]

# %% [markdown]
# ## A-4 Your turn 試試?
# * 实践如下

# %%
# groupby ... agg
df = pd.read_csv ("20春_pandas_week02_hurun_unicorn.tsv", encoding = "utf8", sep="\t")
# df.info() # 注意看Dtype! 
分进合击初阶 = df.groupby(by= ["城市", "行业"]) \
                .agg({"估值（亿人民币）":"sum"}) 
分进合击初阶
# Out:
#                                 估值（亿人民币）
# 城市                       行业
# -                        云计算          70
#                          区块链         150
#                          消费品         150
# Burlington Massachussets 3D印刷        150
# Emerville                网络安全        500
# ...                                  ...
# 香港                       物流           70
#                          电子商务        100
#                          金融科技        140
# 马卡迪                      房地产科技        70
# 马德里                      共享经济         70
#
# [298 rows x 1 columns]

# %%
# groupby ... agg  ... pivot
分进合击迸阶pv = df.groupby(by= ["城市","行业"]) \
                  .agg({"估值（亿人民币）":"sum"}) \
                  .reset_index() \
                  .set_index(["城市"]) \
                  .pivot(columns="行业", values="估值（亿人民币）")
print (分进合击迸阶pv.shape)
分进合击迸阶pv
# Out:
# (120, 25)
# 行业                         3D印刷   云计算   人工智能  健康科技  共享经济    区块链  即时通讯  大数据  \
# 城市
# -                           NaN  70.0    NaN   NaN   NaN  150.0   NaN  NaN
# Burlington Massachussets  150.0   NaN    NaN   NaN   NaN    NaN   NaN  NaN
# Emerville                   NaN   NaN    NaN   NaN   NaN    NaN   NaN  NaN
# Foster City                 NaN   NaN  200.0   NaN   NaN    NaN   NaN  NaN
# Guilford                    NaN   NaN    NaN  70.0   NaN    NaN   NaN  NaN
# ...                         ...   ...    ...   ...   ...    ...   ...  ...
# 青岛                          NaN   NaN    NaN   NaN   NaN    NaN   NaN  NaN
# 首尔                          NaN   NaN    NaN   NaN   NaN    NaN   NaN  NaN
# 香港                          NaN   NaN    NaN   NaN   NaN  150.0   NaN  NaN
# 马卡迪                         NaN   NaN    NaN   NaN   NaN    NaN   NaN  NaN
# 马德里                         NaN   NaN    NaN   NaN  70.0    NaN   NaN  NaN
#
# 行业                        媒体和娱乐  房地产科技  ...    消费品  游戏     物流  生命科学   电子商务  \
# 城市                                      ...
# -                           NaN    NaN  ...  150.0 NaN    NaN   NaN    NaN
# Burlington Massachussets    NaN    NaN  ...    NaN NaN    NaN   NaN    NaN
# Emerville                   NaN    NaN  ...    NaN NaN    NaN   NaN    NaN
# Foster City                 NaN    NaN  ...    NaN NaN    NaN   NaN    NaN
# Guilford                    NaN    NaN  ...    NaN NaN    NaN   NaN    NaN
# ...                         ...    ...  ...    ...  ..    ...   ...    ...
# 青岛                          NaN    NaN  ...    NaN NaN  100.0   NaN    NaN
# 首尔                          NaN    NaN  ...    NaN NaN  200.0   NaN  740.0
# 香港                          NaN    NaN  ...    NaN NaN   70.0   NaN  100.0
# 马卡迪                         NaN   70.0  ...    NaN NaN    NaN   NaN    NaN
# 马德里                         NaN    NaN  ...    NaN NaN    NaN   NaN    NaN
#
# 行业                         网络安全  航天  虚拟与增强现实  软件与服务   金融科技
# 城市
# -                           NaN NaN      NaN    NaN    NaN
# Burlington Massachussets    NaN NaN      NaN    NaN    NaN
# Emerville                 500.0 NaN      NaN    NaN    NaN
# Foster City                 NaN NaN      NaN    NaN    NaN
# Guilford                    NaN NaN      NaN    NaN    NaN
# ...                         ...  ..      ...    ...    ...
# 青岛                          NaN NaN      NaN    NaN    NaN
# 首尔                          NaN NaN      NaN    NaN   70.0
# 香港                          NaN NaN      NaN    NaN  140.0
# 马卡迪                         NaN NaN      NaN    NaN    NaN
# 马德里                         NaN NaN      NaN    NaN    NaN
#
# [120 rows x 25 columns]

# %%
# pivot_table
分进合击迸阶 = df.pivot_table(index= "城市", columns="行业",  \
                 values="估值（亿人民币）", aggfunc="sum") 
print (分进合击迸阶.shape)
分进合击迸阶
# Out:
# (120, 25)
# 行业                         3D印刷   云计算   人工智能  健康科技  共享经济    区块链  即时通讯  大数据  \
# 城市
# -                           NaN  70.0    NaN   NaN   NaN  150.0   NaN  NaN
# Burlington Massachussets  150.0   NaN    NaN   NaN   NaN    NaN   NaN  NaN
# Emerville                   NaN   NaN    NaN   NaN   NaN    NaN   NaN  NaN
# Foster City                 NaN   NaN  200.0   NaN   NaN    NaN   NaN  NaN
# Guilford                    NaN   NaN    NaN  70.0   NaN    NaN   NaN  NaN
# ...                         ...   ...    ...   ...   ...    ...   ...  ...
# 青岛                          NaN   NaN    NaN   NaN   NaN    NaN   NaN  NaN
# 首尔                          NaN   NaN    NaN   NaN   NaN    NaN   NaN  NaN
# 香港                          NaN   NaN    NaN   NaN   NaN  150.0   NaN  NaN
# 马卡迪                         NaN   NaN    NaN   NaN   NaN    NaN   NaN  NaN
# 马德里                         NaN   NaN    NaN   NaN  70.0    NaN   NaN  NaN
#
# 行业                        媒体和娱乐  房地产科技  ...    消费品  游戏     物流  生命科学   电子商务  \
# 城市                                      ...
# -                           NaN    NaN  ...  150.0 NaN    NaN   NaN    NaN
# Burlington Massachussets    NaN    NaN  ...    NaN NaN    NaN   NaN    NaN
# Emerville                   NaN    NaN  ...    NaN NaN    NaN   NaN    NaN
# Foster City                 NaN    NaN  ...    NaN NaN    NaN   NaN    NaN
# Guilford                    NaN    NaN  ...    NaN NaN    NaN   NaN    NaN
# ...                         ...    ...  ...    ...  ..    ...   ...    ...
# 青岛                          NaN    NaN  ...    NaN NaN  100.0   NaN    NaN
# 首尔                          NaN    NaN  ...    NaN NaN  200.0   NaN  740.0
# 香港                          NaN    NaN  ...    NaN NaN   70.0   NaN  100.0
# 马卡迪                         NaN   70.0  ...    NaN NaN    NaN   NaN    NaN
# 马德里                         NaN    NaN  ...    NaN NaN    NaN   NaN    NaN
#
# 行业                         网络安全  航天  虚拟与增强现实  软件与服务   金融科技
# 城市
# -                           NaN NaN      NaN    NaN    NaN
# Burlington Massachussets    NaN NaN      NaN    NaN    NaN
# Emerville                 500.0 NaN      NaN    NaN    NaN
# Foster City                 NaN NaN      NaN    NaN    NaN
# Guilford                    NaN NaN      NaN    NaN    NaN
# ...                         ...  ..      ...    ...    ...
# 青岛                          NaN NaN      NaN    NaN    NaN
# 首尔                          NaN NaN      NaN    NaN   70.0
# 香港                          NaN NaN      NaN    NaN  140.0
# 马卡迪                         NaN NaN      NaN    NaN    NaN
# 马德里                         NaN NaN      NaN    NaN    NaN
#
# [120 rows x 25 columns]

# %%
# pivot_table 按总值排序
排序 = 分进合击迸阶.sum(axis=1).sort_values(ascending=False).index
排序
排序_总值 = 分进合击迸阶.sum(axis=1).sort_values(ascending=False).values
排序_总值
分进合击迸阶_排序过 =  分进合击迸阶.loc[排序]
分进合击迸阶_排序过
分进合击迸阶_排序过['总值'] = 排序_总值
分进合击迸阶_排序过
# Out:
# 行业       3D印刷     云计算    人工智能   健康科技    共享经济    区块链   即时通讯    大数据   媒体和娱乐  \
# 城市
# 北京        NaN   220.0  1430.0  380.0  4040.0  800.0    NaN  380.0  6890.0
# 旧金山       NaN  1660.0   140.0  140.0  2770.0  970.0  370.0  200.0   200.0
# 杭州        NaN   170.0   100.0  470.0   100.0  300.0    NaN  100.0   100.0
# 上海        NaN    70.0   290.0  970.0   200.0    NaN    NaN   70.0   590.0
# 纽约        NaN  3950.0   720.0  350.0  2100.0    NaN    NaN   70.0   150.0
# ...       ...     ...     ...    ...     ...    ...    ...    ...     ...
# 圣卡洛斯      NaN     NaN     NaN    NaN     NaN    NaN    NaN   70.0     NaN
# 盐湖城       NaN     NaN     NaN    NaN     NaN    NaN    NaN   70.0     NaN
# 布宜诺斯艾利斯   NaN    70.0     NaN    NaN     NaN    NaN    NaN    NaN     NaN
# 台北        NaN     NaN     NaN    NaN     NaN    NaN    NaN    NaN     NaN
# 马德里       NaN     NaN     NaN    NaN    70.0    NaN    NaN    NaN     NaN
#
# 行业       房地产科技  ...     游戏      物流   生命科学    电子商务   网络安全  航天  虚拟与增强现实  软件与服务  \
# 城市              ...
# 北京       500.0  ...  100.0  1040.0  140.0  2300.0  200.0 NaN      NaN  630.0
# 旧金山       70.0  ...  200.0  1870.0    NaN  1110.0  140.0 NaN    300.0    NaN
# 杭州         NaN  ...    NaN  1300.0    NaN   360.0    NaN NaN      NaN    NaN
# 上海       170.0  ...    NaN   440.0  300.0   780.0    NaN NaN      NaN  420.0
# 纽约        70.0  ...    NaN   150.0    NaN   510.0    NaN NaN      NaN   70.0
# ...        ...  ...    ...     ...    ...     ...    ...  ..      ...    ...
# 圣卡洛斯       NaN  ...    NaN     NaN    NaN     NaN    NaN NaN      NaN    NaN
# 盐湖城        NaN  ...    NaN     NaN    NaN     NaN    NaN NaN      NaN    NaN
# 布宜诺斯艾利斯    NaN  ...    NaN     NaN    NaN     NaN    NaN NaN      NaN    NaN
# 台北         NaN  ...    NaN     NaN    NaN     NaN    NaN NaN      NaN    NaN
# 马德里        NaN  ...    NaN     NaN    NaN     NaN    NaN NaN      NaN    NaN
#
# 行业          金融科技       总值
# 城市
# 北京        1920.0  22130.0
# 旧金山       3100.0  17060.0
# 杭州       10290.0  13290.0
# 上海        3470.0   8990.0
# 纽约         220.0   8640.0
# ...          ...      ...
# 圣卡洛斯         NaN     70.0
# 盐湖城          NaN     70.0
# 布宜诺斯艾利斯      NaN     70.0
# 台北           NaN     70.0
# 马德里          NaN     70.0
#
# [120 rows x 26 columns]

# %% [markdown]
# # 数据框排序（sorted_values）
# 交叉报表的排序较为复杂，有两维可以排序
#
# ## 排序B-1 sort_index axis=0
#
# ![](https://upload-images.jianshu.io/upload_images/2233157-b77105789e36c847.jpg)
#
#
# Series.sort_values（self，axis = 0，ascending = True，inplace = False，kind =' quicksort '，na_position ='last'，ignore_index = False ）
# * Series.sort_index (By index)
# 按系列索引排序。
#
# * DataFrame.sort_values  (By values)
# 通过沿任一轴的值对DataFrame进行排序。
#
# * DataFrame.sort_index  (By index)
# 按索引对DataFrame进行排序。
#
# * By indexes and values
#
# 更多排序内容请参见[basics-sorting](https://pandas.pydata.org/pandas-docs/stable/getting_started/basics.html#basics-sorting)

# %%
# B-1
分进合击迸阶.sort_index(axis=0, ascending=False)
# Out:
# 成立年份    2000   2001    2002   2003    2004   2005    2006    2007    2008  \
# 国家
# 马耳他      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 韩国       NaN    NaN     NaN    NaN     NaN   70.0     NaN   350.0     NaN
# 阿根廷      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 西班牙      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 菲律宾      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 英国       NaN    NaN     NaN    NaN   350.0  150.0     NaN     NaN     NaN
# 芬兰       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 美国     210.0  210.0  6270.0  420.0  1550.0  840.0   810.0  2650.0  4570.0
# 瑞士       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 瑞典       NaN    NaN     NaN    NaN     NaN  300.0     NaN     NaN     NaN
# 爱沙尼亚     NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 爱尔兰    150.0    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 澳大利亚     NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 法国       NaN    NaN     NaN    NaN     NaN    NaN   220.0     NaN     NaN
# 日本       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 新加坡      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 德国     150.0    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 巴西       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 哥伦比亚     NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 印度尼西亚    NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 印度     150.0    NaN     NaN    NaN   150.0    NaN     NaN    70.0   840.0
# 卢森堡      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 以色列      NaN    NaN   150.0    NaN     NaN    NaN     NaN     NaN     NaN
# 中国     170.0  170.0   200.0  200.0   100.0  300.0  2380.0  1280.0   710.0
#
# 成立年份     2009    2010    2011     2012    2013     2014    2015    2016  \
# 国家
# 马耳他       NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 韩国        NaN   670.0   270.0      NaN     NaN      NaN     NaN     NaN
# 阿根廷       NaN     NaN     NaN      NaN    70.0      NaN     NaN     NaN
# 西班牙       NaN     NaN    70.0      NaN     NaN      NaN     NaN     NaN
# 菲律宾       NaN     NaN     NaN      NaN     NaN      NaN    70.0     NaN
# 英国       70.0     NaN   550.0    450.0   350.0      NaN   350.0   150.0
# 芬兰        NaN     NaN     NaN      NaN     NaN      NaN     NaN    70.0
# 美国     2090.0  6150.0  2620.0   4670.0  3840.0   2220.0  5980.0  1690.0
# 瑞士        NaN     NaN     NaN     70.0     NaN    500.0   150.0     NaN
# 瑞典        NaN     NaN     NaN      NaN     NaN      NaN     NaN   150.0
# 爱沙尼亚      NaN     NaN     NaN      NaN    70.0      NaN     NaN     NaN
# 爱尔兰       NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 澳大利亚      NaN     NaN     NaN    200.0     NaN      NaN     NaN     NaN
# 法国        NaN     NaN     NaN      NaN    70.0      NaN     NaN    70.0
# 日本        NaN     NaN     NaN      NaN     NaN    220.0     NaN     NaN
# 新加坡       NaN     NaN     NaN   1350.0     NaN      NaN     NaN     NaN
# 德国       70.0     NaN   150.0    370.0   200.0     70.0     NaN     NaN
# 巴西        NaN     NaN    70.0     70.0   370.0      NaN     NaN     NaN
# 哥伦比亚      NaN     NaN     NaN      NaN     NaN      NaN     NaN    70.0
# 印度尼西亚   500.0   700.0    70.0    300.0     NaN      NaN     NaN     NaN
# 印度        NaN  1300.0   440.0    140.0   350.0    270.0     NaN    70.0
# 卢森堡       NaN     NaN     NaN      NaN     NaN     70.0     NaN     NaN
# 以色列       NaN   210.0   150.0    150.0    70.0      NaN     NaN     NaN
# 中国      950.0  1590.0  6570.0  11330.0  5340.0  16150.0  3960.0  1300.0
#
# 成立年份    2017    2018   2019
# 国家
# 马耳他    150.0     NaN    NaN
# 韩国       NaN     NaN    NaN
# 阿根廷      NaN     NaN    NaN
# 西班牙      NaN     NaN    NaN
# 菲律宾      NaN     NaN    NaN
# 英国       NaN     NaN    NaN
# 芬兰       NaN     NaN    NaN
# 美国     870.0     NaN   70.0
# 瑞士       NaN     NaN    NaN
# 瑞典       NaN     NaN    NaN
# 爱沙尼亚     NaN     NaN    NaN
# 爱尔兰      NaN     NaN    NaN
# 澳大利亚     NaN     NaN    NaN
# 法国       NaN     NaN    NaN
# 日本       NaN     NaN    NaN
# 新加坡      NaN     NaN    NaN
# 德国       NaN     NaN    NaN
# 巴西       NaN     NaN    NaN
# 哥伦比亚     NaN     NaN    NaN
# 印度尼西亚    NaN     NaN    NaN
# 印度      70.0     NaN    NaN
# 卢森堡      NaN     NaN    NaN
# 以色列      NaN     NaN    NaN
# 中国     810.0  1090.0  100.0

# %% [markdown]
# ## 排序B-2 sort_index axis=1

# %%
# B-2
分进合击迸阶.sort_index(axis=1, ascending=False)
# Out:
# 成立年份    2019    2018   2017    2016    2015     2014    2013     2012    2011  \
# 国家
# 中国     100.0  1090.0  810.0  1300.0  3960.0  16150.0  5340.0  11330.0  6570.0
# 以色列      NaN     NaN    NaN     NaN     NaN      NaN    70.0    150.0   150.0
# 卢森堡      NaN     NaN    NaN     NaN     NaN     70.0     NaN      NaN     NaN
# 印度       NaN     NaN   70.0    70.0     NaN    270.0   350.0    140.0   440.0
# 印度尼西亚    NaN     NaN    NaN     NaN     NaN      NaN     NaN    300.0    70.0
# 哥伦比亚     NaN     NaN    NaN    70.0     NaN      NaN     NaN      NaN     NaN
# 巴西       NaN     NaN    NaN     NaN     NaN      NaN   370.0     70.0    70.0
# 德国       NaN     NaN    NaN     NaN     NaN     70.0   200.0    370.0   150.0
# 新加坡      NaN     NaN    NaN     NaN     NaN      NaN     NaN   1350.0     NaN
# 日本       NaN     NaN    NaN     NaN     NaN    220.0     NaN      NaN     NaN
# 法国       NaN     NaN    NaN    70.0     NaN      NaN    70.0      NaN     NaN
# 澳大利亚     NaN     NaN    NaN     NaN     NaN      NaN     NaN    200.0     NaN
# 爱尔兰      NaN     NaN    NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 爱沙尼亚     NaN     NaN    NaN     NaN     NaN      NaN    70.0      NaN     NaN
# 瑞典       NaN     NaN    NaN   150.0     NaN      NaN     NaN      NaN     NaN
# 瑞士       NaN     NaN    NaN     NaN   150.0    500.0     NaN     70.0     NaN
# 美国      70.0     NaN  870.0  1690.0  5980.0   2220.0  3840.0   4670.0  2620.0
# 芬兰       NaN     NaN    NaN    70.0     NaN      NaN     NaN      NaN     NaN
# 英国       NaN     NaN    NaN   150.0   350.0      NaN   350.0    450.0   550.0
# 菲律宾      NaN     NaN    NaN     NaN    70.0      NaN     NaN      NaN     NaN
# 西班牙      NaN     NaN    NaN     NaN     NaN      NaN     NaN      NaN    70.0
# 阿根廷      NaN     NaN    NaN     NaN     NaN      NaN    70.0      NaN     NaN
# 韩国       NaN     NaN    NaN     NaN     NaN      NaN     NaN      NaN   270.0
# 马耳他      NaN     NaN  150.0     NaN     NaN      NaN     NaN      NaN     NaN
#
# 成立年份     2010    2009    2008    2007    2006   2005    2004   2003    2002  \
# 国家
# 中国     1590.0   950.0   710.0  1280.0  2380.0  300.0   100.0  200.0   200.0
# 以色列     210.0     NaN     NaN     NaN     NaN    NaN     NaN    NaN   150.0
# 卢森堡       NaN     NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 印度     1300.0     NaN   840.0    70.0     NaN    NaN   150.0    NaN     NaN
# 印度尼西亚   700.0   500.0     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 哥伦比亚      NaN     NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 巴西        NaN     NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 德国        NaN    70.0     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 新加坡       NaN     NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 日本        NaN     NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 法国        NaN     NaN     NaN     NaN   220.0    NaN     NaN    NaN     NaN
# 澳大利亚      NaN     NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 爱尔兰       NaN     NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 爱沙尼亚      NaN     NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 瑞典        NaN     NaN     NaN     NaN     NaN  300.0     NaN    NaN     NaN
# 瑞士        NaN     NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 美国     6150.0  2090.0  4570.0  2650.0   810.0  840.0  1550.0  420.0  6270.0
# 芬兰        NaN     NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 英国        NaN    70.0     NaN     NaN     NaN  150.0   350.0    NaN     NaN
# 菲律宾       NaN     NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 西班牙       NaN     NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 阿根廷       NaN     NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 韩国      670.0     NaN     NaN   350.0     NaN   70.0     NaN    NaN     NaN
# 马耳他       NaN     NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
#
# 成立年份    2001   2000
# 国家
# 中国     170.0  170.0
# 以色列      NaN    NaN
# 卢森堡      NaN    NaN
# 印度       NaN  150.0
# 印度尼西亚    NaN    NaN
# 哥伦比亚     NaN    NaN
# 巴西       NaN    NaN
# 德国       NaN  150.0
# 新加坡      NaN    NaN
# 日本       NaN    NaN
# 法国       NaN    NaN
# 澳大利亚     NaN    NaN
# 爱尔兰      NaN  150.0
# 爱沙尼亚     NaN    NaN
# 瑞典       NaN    NaN
# 瑞士       NaN    NaN
# 美国     210.0  210.0
# 芬兰       NaN    NaN
# 英国       NaN    NaN
# 菲律宾      NaN    NaN
# 西班牙      NaN    NaN
# 阿根廷      NaN    NaN
# 韩国       NaN    NaN
# 马耳他      NaN    NaN

# %% [markdown]
# ## 排序B-3 sort_values

# %%
# B-3 同 # A-3，一步步观察并学习
排序 = 分进合击迸阶.sum(axis=1).sort_values(ascending=False).index
排序
#排序_总值 = 分进合击迸阶.sum(axis=1).sort_values(ascending=False).values
#分进合击迸阶_排序过 =  分进合击迸阶.loc[排序]
#分进合击迸阶_排序过['总值'] = 排序_总值
#分进合击迸阶_排序过
# Out:
# Index(['中国', '美国', '印度', '英国', '印度尼西亚', '韩国', '新加坡', '德国', '以色列', '瑞士', '巴西',
#        '瑞典', '法国', '日本', '澳大利亚', '爱尔兰', '马耳他', '爱沙尼亚', '芬兰', '哥伦比亚', '菲律宾',
#        '西班牙', '卢森堡', '阿根廷'],
#       dtype='object', name='国家')

# %% [markdown]
# #  pivot说明
#
# ## pivot 长框变宽框
#
# ![](https://pandas.pydata.org/pandas-docs/stable/_images/07_pivot.svg)

# %% [markdown]
# ### 分+进
#
# 1. groupby 分组
# 2. agg 计算

# %%
# C-1 迸阶A-1分解动作 groupby
分进合击初阶 = df.groupby(by= ["国家", "成立年份"]) \
                .agg({"估值（亿人民币）":"sum"})
分进合击初阶
# Out:
#           估值（亿人民币）
# 国家  成立年份
# 中国  2000       170
#     2001       170
#     2002       200
#     2003       200
#     2004       100
# ...            ...
# 韩国  2005        70
#     2007       350
#     2010       670
#     2011       270
# 马耳他 2017       150
#
# [100 rows x 1 columns]

# %% [markdown]
# ### reset_index
#
# * #D-1 reset_index 进行默认索引，取消groupby分组,将组别变成普通的列

# %%
# C-2 迸阶A-2分解动作 
分进合击初阶.reset_index()
# Out:
#      国家  成立年份  估值（亿人民币）
# 0    中国  2000       170
# 1    中国  2001       170
# 2    中国  2002       200
# 3    中国  2003       200
# 4    中国  2004       100
# ..  ...   ...       ...
# 95   韩国  2005        70
# 96   韩国  2007       350
# 97   韩国  2010       670
# 98   韩国  2011       270
# 99  马耳他  2017       150
#
# [100 rows x 3 columns]

# %% [markdown]
# ### pivot 指定列index、行columns、值values

# %%
# C-3 迸阶A-2分解动作
分进合击初阶_pivot = 分进合击初阶.reset_index().pivot(index = '成立年份',columns='国家' ,values='估值（亿人民币）' )
分进合击初阶_pivot
# Out:
# 国家         中国    以色列   卢森堡      印度  印度尼西亚  哥伦比亚     巴西     德国     新加坡     日本  \
# 成立年份
# 2000    170.0    NaN   NaN   150.0    NaN   NaN    NaN  150.0     NaN    NaN
# 2001    170.0    NaN   NaN     NaN    NaN   NaN    NaN    NaN     NaN    NaN
# 2002    200.0  150.0   NaN     NaN    NaN   NaN    NaN    NaN     NaN    NaN
# 2003    200.0    NaN   NaN     NaN    NaN   NaN    NaN    NaN     NaN    NaN
# 2004    100.0    NaN   NaN   150.0    NaN   NaN    NaN    NaN     NaN    NaN
# 2005    300.0    NaN   NaN     NaN    NaN   NaN    NaN    NaN     NaN    NaN
# 2006   2380.0    NaN   NaN     NaN    NaN   NaN    NaN    NaN     NaN    NaN
# 2007   1280.0    NaN   NaN    70.0    NaN   NaN    NaN    NaN     NaN    NaN
# 2008    710.0    NaN   NaN   840.0    NaN   NaN    NaN    NaN     NaN    NaN
# 2009    950.0    NaN   NaN     NaN  500.0   NaN    NaN   70.0     NaN    NaN
# 2010   1590.0  210.0   NaN  1300.0  700.0   NaN    NaN    NaN     NaN    NaN
# 2011   6570.0  150.0   NaN   440.0   70.0   NaN   70.0  150.0     NaN    NaN
# 2012  11330.0  150.0   NaN   140.0  300.0   NaN   70.0  370.0  1350.0    NaN
# 2013   5340.0   70.0   NaN   350.0    NaN   NaN  370.0  200.0     NaN    NaN
# 2014  16150.0    NaN  70.0   270.0    NaN   NaN    NaN   70.0     NaN  220.0
# 2015   3960.0    NaN   NaN     NaN    NaN   NaN    NaN    NaN     NaN    NaN
# 2016   1300.0    NaN   NaN    70.0    NaN  70.0    NaN    NaN     NaN    NaN
# 2017    810.0    NaN   NaN    70.0    NaN   NaN    NaN    NaN     NaN    NaN
# 2018   1090.0    NaN   NaN     NaN    NaN   NaN    NaN    NaN     NaN    NaN
# 2019    100.0    NaN   NaN     NaN    NaN   NaN    NaN    NaN     NaN    NaN
#
# 国家    ...     瑞典     瑞士      美国    芬兰     英国   菲律宾   西班牙   阿根廷     韩国    马耳他
# 成立年份  ...
# 2000  ...    NaN    NaN   210.0   NaN    NaN   NaN   NaN   NaN    NaN    NaN
# 2001  ...    NaN    NaN   210.0   NaN    NaN   NaN   NaN   NaN    NaN    NaN
# 2002  ...    NaN    NaN  6270.0   NaN    NaN   NaN   NaN   NaN    NaN    NaN
# 2003  ...    NaN    NaN   420.0   NaN    NaN   NaN   NaN   NaN    NaN    NaN
# 2004  ...    NaN    NaN  1550.0   NaN  350.0   NaN   NaN   NaN    NaN    NaN
# 2005  ...  300.0    NaN   840.0   NaN  150.0   NaN   NaN   NaN   70.0    NaN
# 2006  ...    NaN    NaN   810.0   NaN    NaN   NaN   NaN   NaN    NaN    NaN
# 2007  ...    NaN    NaN  2650.0   NaN    NaN   NaN   NaN   NaN  350.0    NaN
# 2008  ...    NaN    NaN  4570.0   NaN    NaN   NaN   NaN   NaN    NaN    NaN
# 2009  ...    NaN    NaN  2090.0   NaN   70.0   NaN   NaN   NaN    NaN    NaN
# 2010  ...    NaN    NaN  6150.0   NaN    NaN   NaN   NaN   NaN  670.0    NaN
# 2011  ...    NaN    NaN  2620.0   NaN  550.0   NaN  70.0   NaN  270.0    NaN
# 2012  ...    NaN   70.0  4670.0   NaN  450.0   NaN   NaN   NaN    NaN    NaN
# 2013  ...    NaN    NaN  3840.0   NaN  350.0   NaN   NaN  70.0    NaN    NaN
# 2014  ...    NaN  500.0  2220.0   NaN    NaN   NaN   NaN   NaN    NaN    NaN
# 2015  ...    NaN  150.0  5980.0   NaN  350.0  70.0   NaN   NaN    NaN    NaN
# 2016  ...  150.0    NaN  1690.0  70.0  150.0   NaN   NaN   NaN    NaN    NaN
# 2017  ...    NaN    NaN   870.0   NaN    NaN   NaN   NaN   NaN    NaN  150.0
# 2018  ...    NaN    NaN     NaN   NaN    NaN   NaN   NaN   NaN    NaN    NaN
# 2019  ...    NaN    NaN    70.0   NaN    NaN   NaN   NaN   NaN    NaN    NaN
#
# [20 rows x 24 columns]

# %%
# C-4 plot
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['Songti SC']
分进合击初阶_pivot.plot(figsize=(16,8))
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 25104 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 31435 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 25104 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 31435 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23478 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20013 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20197 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 33394 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21015 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21346 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26862 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22561 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21360 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24230 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20122 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21733 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20262 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27604 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24052 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24503 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22369 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26412 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27861 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 28595 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22823 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21033 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29233 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23572 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20848 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27801 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29790 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20856 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22763 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32654 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 33452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 33521 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 33778 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24459 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23486 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29677 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29273 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 38463 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26681 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24311 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 38889 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 39532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32819 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20182 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23478 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20013 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20197 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 33394 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21015 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21346 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26862 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22561 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21360 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24230 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23612 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20122 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21733 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20262 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27604 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24052 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24503 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22369 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26412 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27861 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 28595 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22823 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21033 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 29233 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23572 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20848 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27801 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 29790 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20856 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22763 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32654 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 33452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 33521 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 33778 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24459 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23486 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 29677 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 29273 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 38463 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26681 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24311 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 38889 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 39532 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32819 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20182 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ![](https://pandas.pydata.org/pandas-docs/stable/_images/07_pivot_table.svg)
#
# #  pivot_table说明
#
# * [什么是透视表？](https://zhuanlan.zhihu.com/p/31952948)
#
#
# ## pivot_table 长框变宽框
# pivot_table 分解动作及作图
#
# ### pivot_table
# * pivot_table 比pivot 多function运算
# * 这样相当于groupby+agg+pivot 的结果可用更好的pivot_table
#
# 上面两代碼等价，pivot_table仿佛是加入了columns与margin功能的groupby函数，比groupby更加灵活。

# %% [markdown]
# -----
#
#
# ## 以下小心使用, 不然就刪
#
#
#
# -----

# %%
# D-0
df.groupby(["国家","成立年份"]).agg({"估值（亿人民币）":sum}).fillna(0)
# Out:
#           估值（亿人民币）
# 国家  成立年份
# 中国  2000       170
#     2001       170
#     2002       200
#     2003       200
#     2004       100
# ...            ...
# 韩国  2005        70
#     2007       350
#     2010       670
#     2011       270
# 马耳他 2017       150
#
# [100 rows x 1 columns]

# %%
# D-1
df.groupby(["国家","成立年份"])[["估值（亿人民币）"]].sum()
# Out:
#           估值（亿人民币）
# 国家  成立年份
# 中国  2000       170
#     2001       170
#     2002       200
#     2003       200
#     2004       100
# ...            ...
# 韩国  2005        70
#     2007       350
#     2010       670
#     2011       270
# 马耳他 2017       150
#
# [100 rows x 1 columns]

# %%
# D-2
分进合击初阶_pivot_table = 分进合击初阶.reset_index().pivot_table(index = '国家' ,columns='成立年份',values='估值（亿人民币）',aggfunc="sum")
分进合击初阶_pivot_table
# Out:
# 成立年份    2000   2001    2002   2003    2004   2005    2006    2007    2008  \
# 国家
# 中国     170.0  170.0   200.0  200.0   100.0  300.0  2380.0  1280.0   710.0
# 以色列      NaN    NaN   150.0    NaN     NaN    NaN     NaN     NaN     NaN
# 卢森堡      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 印度     150.0    NaN     NaN    NaN   150.0    NaN     NaN    70.0   840.0
# 印度尼西亚    NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 哥伦比亚     NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 巴西       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 德国     150.0    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 新加坡      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 日本       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 法国       NaN    NaN     NaN    NaN     NaN    NaN   220.0     NaN     NaN
# 澳大利亚     NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 爱尔兰    150.0    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 爱沙尼亚     NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 瑞典       NaN    NaN     NaN    NaN     NaN  300.0     NaN     NaN     NaN
# 瑞士       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 美国     210.0  210.0  6270.0  420.0  1550.0  840.0   810.0  2650.0  4570.0
# 芬兰       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 英国       NaN    NaN     NaN    NaN   350.0  150.0     NaN     NaN     NaN
# 菲律宾      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 西班牙      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 阿根廷      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 韩国       NaN    NaN     NaN    NaN     NaN   70.0     NaN   350.0     NaN
# 马耳他      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
#
# 成立年份     2009    2010    2011     2012    2013     2014    2015    2016  \
# 国家
# 中国      950.0  1590.0  6570.0  11330.0  5340.0  16150.0  3960.0  1300.0
# 以色列       NaN   210.0   150.0    150.0    70.0      NaN     NaN     NaN
# 卢森堡       NaN     NaN     NaN      NaN     NaN     70.0     NaN     NaN
# 印度        NaN  1300.0   440.0    140.0   350.0    270.0     NaN    70.0
# 印度尼西亚   500.0   700.0    70.0    300.0     NaN      NaN     NaN     NaN
# 哥伦比亚      NaN     NaN     NaN      NaN     NaN      NaN     NaN    70.0
# 巴西        NaN     NaN    70.0     70.0   370.0      NaN     NaN     NaN
# 德国       70.0     NaN   150.0    370.0   200.0     70.0     NaN     NaN
# 新加坡       NaN     NaN     NaN   1350.0     NaN      NaN     NaN     NaN
# 日本        NaN     NaN     NaN      NaN     NaN    220.0     NaN     NaN
# 法国        NaN     NaN     NaN      NaN    70.0      NaN     NaN    70.0
# 澳大利亚      NaN     NaN     NaN    200.0     NaN      NaN     NaN     NaN
# 爱尔兰       NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 爱沙尼亚      NaN     NaN     NaN      NaN    70.0      NaN     NaN     NaN
# 瑞典        NaN     NaN     NaN      NaN     NaN      NaN     NaN   150.0
# 瑞士        NaN     NaN     NaN     70.0     NaN    500.0   150.0     NaN
# 美国     2090.0  6150.0  2620.0   4670.0  3840.0   2220.0  5980.0  1690.0
# 芬兰        NaN     NaN     NaN      NaN     NaN      NaN     NaN    70.0
# 英国       70.0     NaN   550.0    450.0   350.0      NaN   350.0   150.0
# 菲律宾       NaN     NaN     NaN      NaN     NaN      NaN    70.0     NaN
# 西班牙       NaN     NaN    70.0      NaN     NaN      NaN     NaN     NaN
# 阿根廷       NaN     NaN     NaN      NaN    70.0      NaN     NaN     NaN
# 韩国        NaN   670.0   270.0      NaN     NaN      NaN     NaN     NaN
# 马耳他       NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
#
# 成立年份    2017    2018   2019
# 国家
# 中国     810.0  1090.0  100.0
# 以色列      NaN     NaN    NaN
# 卢森堡      NaN     NaN    NaN
# 印度      70.0     NaN    NaN
# 印度尼西亚    NaN     NaN    NaN
# 哥伦比亚     NaN     NaN    NaN
# 巴西       NaN     NaN    NaN
# 德国       NaN     NaN    NaN
# 新加坡      NaN     NaN    NaN
# 日本       NaN     NaN    NaN
# 法国       NaN     NaN    NaN
# 澳大利亚     NaN     NaN    NaN
# 爱尔兰      NaN     NaN    NaN
# 爱沙尼亚     NaN     NaN    NaN
# 瑞典       NaN     NaN    NaN
# 瑞士       NaN     NaN    NaN
# 美国     870.0     NaN   70.0
# 芬兰       NaN     NaN    NaN
# 英国       NaN     NaN    NaN
# 菲律宾      NaN     NaN    NaN
# 西班牙      NaN     NaN    NaN
# 阿根廷      NaN     NaN    NaN
# 韩国       NaN     NaN    NaN
# 马耳他    150.0     NaN    NaN

# %%
# %matplotlib --list
# D-3
分进合击初阶_pivot_table.plot(figsize=(16,8))
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20013 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21733 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20262 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27604 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20122 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27861 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29790 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22763 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29677 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29273 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20013 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21733 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20262 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27604 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20122 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27861 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 29790 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22763 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 29677 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 29273 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23478 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23478 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 25104 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 31435 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 25104 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 31435 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20221 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # 练习：按照年份，将不同行业的估值趋势进行描述

# %% [markdown]
# ## 数据框出交叉报表

# %%
# groupby ... agg
df = pd.read_csv ("20春_pandas_week02_hurun_unicorn.tsv", encoding = "utf8", sep="\t")
# df.info() # 注意看Dtype! 
分进合击初阶 = df.groupby(by= ["行业", "成立年份"]) \
                .agg({"估值（亿人民币）":"sum"}) 
分进合击初阶
# Out:
#            估值（亿人民币）
# 行业   成立年份
# 3D印刷 2011        70
#      2013       150
#      2015       150
# 云计算  2000       290
#      2001        70
# ...             ...
# 金融科技 2014     11570
#      2015      1290
#      2016       210
#      2017       200
#      2018       200
#
# [212 rows x 1 columns]

# %%
# pivot处理
分进合击迸阶pv = df.groupby(by= ["行业","成立年份"]) \
                  .agg({"估值（亿人民币）":"sum"}) \
                  .reset_index() \
                  .set_index(["行业"]) \
                  .pivot(columns="成立年份", values="估值（亿人民币）")
print (分进合击迸阶pv.shape)
分进合击迸阶pv
# Out:
# (25, 20)
# 成立年份      2000   2001    2002   2003    2004   2005    2006    2007    2008  \
# 行业
# 3D印刷       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 云计算      290.0   70.0  3500.0  150.0     NaN   70.0     NaN     NaN   290.0
# 人工智能       NaN    NaN     NaN  200.0   150.0  570.0   150.0    70.0     NaN
# 健康科技      70.0   70.0     NaN    NaN     NaN    NaN    70.0   220.0    70.0
# 共享经济       NaN    NaN     NaN    NaN     NaN    NaN   150.0     NaN  2700.0
# 区块链        NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 即时通讯       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 大数据        NaN   70.0     NaN    NaN  1250.0    NaN     NaN     NaN   140.0
# 媒体和娱乐      NaN    NaN     NaN  270.0     NaN  200.0   570.0  1000.0     NaN
# 房地产科技      NaN    NaN   200.0    NaN     NaN    NaN     NaN     NaN     NaN
# 教育科技       NaN   70.0     NaN    NaN     NaN    NaN   100.0   140.0   470.0
# 新能源        NaN    NaN     NaN    NaN     NaN    NaN   140.0   140.0   140.0
# 新能源汽车      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 新零售        NaN    NaN    70.0    NaN     NaN    NaN    70.0    70.0     NaN
# 机器人        NaN    NaN     NaN    NaN     NaN    NaN  1000.0     NaN     NaN
# 消费品        NaN    NaN     NaN    NaN     NaN    NaN   150.0     NaN     NaN
# 游戏         NaN    NaN     NaN    NaN   400.0    NaN     NaN   350.0   350.0
# 物流       100.0    NaN     NaN    NaN     NaN    NaN     NaN  1000.0   300.0
# 生命科学     150.0    NaN     NaN    NaN     NaN  150.0   150.0    70.0   800.0
# 电子商务       NaN    NaN     NaN    NaN   350.0  270.0   150.0   210.0   540.0
# 网络安全       NaN    NaN     NaN    NaN     NaN    NaN     NaN   570.0     NaN
# 航天         NaN    NaN  2500.0    NaN     NaN    NaN    70.0     NaN     NaN
# 虚拟与增强现实    NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 软件与服务      NaN  100.0   150.0    NaN     NaN  100.0     NaN   210.0   100.0
# 金融科技     220.0    NaN   200.0    NaN     NaN  300.0   640.0   300.0   220.0
#
# 成立年份       2009    2010    2011    2012    2013     2014    2015    2016  \
# 行业
# 3D印刷        NaN     NaN    70.0     NaN   150.0      NaN   150.0     NaN
# 云计算       360.0   360.0   670.0   880.0   650.0    540.0   370.0     NaN
# 人工智能      320.0    70.0   440.0   360.0   440.0   1070.0   610.0  1310.0
# 健康科技      250.0   850.0   410.0   340.0   340.0      NaN   140.0   600.0
# 共享经济       70.0  3200.0   170.0  4600.0   420.0      NaN  1270.0   270.0
# 区块链         NaN     NaN    70.0   900.0  1300.0     70.0   150.0     NaN
# 即时通讯       70.0   150.0    70.0   220.0     NaN     70.0     NaN     NaN
# 大数据       100.0   140.0   210.0   370.0   200.0     70.0   170.0     NaN
# 媒体和娱乐     150.0     NaN  1350.0  5340.0   400.0    520.0   220.0     NaN
# 房地产科技       NaN   100.0   440.0   240.0    70.0      NaN   370.0     NaN
# 教育科技        NaN    70.0    70.0   270.0   270.0    340.0     NaN     NaN
# 新能源        70.0     NaN   220.0     NaN     NaN      NaN     NaN   150.0
# 新能源汽车     350.0     NaN     NaN     NaN     NaN   1070.0   520.0     NaN
# 新零售         NaN     NaN   220.0     NaN   220.0      NaN   140.0     NaN
# 机器人         NaN     NaN     NaN   300.0   100.0      NaN     NaN   200.0
# 消费品         NaN   150.0     NaN   370.0     NaN    140.0  3570.0    70.0
# 游戏          NaN     NaN     NaN   440.0     NaN      NaN   100.0     NaN
# 物流          NaN   370.0   740.0   770.0  2610.0   1180.0   360.0    70.0
# 生命科学      270.0   370.0    70.0   220.0    70.0    800.0   300.0   550.0
# 电子商务     1250.0  1750.0  1230.0  1900.0   170.0   1700.0   580.0   140.0
# 网络安全       70.0    70.0     NaN     NaN    70.0      NaN   200.0     NaN
# 航天          NaN     NaN     NaN   200.0     NaN      NaN     NaN     NaN
# 虚拟与增强现实     NaN   300.0   400.0    70.0     NaN      NaN     NaN     NaN
# 软件与服务     140.0   150.0    70.0   320.0   340.0    360.0     NaN     NaN
# 金融科技      210.0  2520.0  4040.0   990.0  2910.0  11570.0  1290.0   210.0
#
# 成立年份      2017   2018   2019
# 行业
# 3D印刷       NaN    NaN    NaN
# 云计算        NaN    NaN    NaN
# 人工智能       NaN    NaN    NaN
# 健康科技     150.0   70.0  100.0
# 共享经济     370.0    NaN    NaN
# 区块链      300.0    NaN    NaN
# 即时通讯       NaN    NaN    NaN
# 大数据        NaN    NaN    NaN
# 媒体和娱乐      NaN    NaN    NaN
# 房地产科技      NaN  600.0    NaN
# 教育科技       NaN    NaN    NaN
# 新能源        NaN    NaN    NaN
# 新能源汽车    590.0    NaN    NaN
# 新零售       70.0   70.0    NaN
# 机器人        NaN    NaN    NaN
# 消费品      150.0  150.0    NaN
# 游戏         NaN    NaN    NaN
# 物流         NaN    NaN    NaN
# 生命科学       NaN    NaN    NaN
# 电子商务      70.0    NaN    NaN
# 网络安全       NaN    NaN   70.0
# 航天         NaN    NaN    NaN
# 虚拟与增强现实    NaN    NaN    NaN
# 软件与服务      NaN    NaN    NaN
# 金融科技     200.0  200.0    NaN

# %%
# pivot_table；总值处理
分进合击迸阶 = df.pivot_table(index= "行业", columns="成立年份",  \
                 values="估值（亿人民币）", aggfunc="sum") 
print (分进合击迸阶.shape)
分进合击迸阶
# Out:
# (25, 20)
# 成立年份      2000   2001    2002   2003    2004   2005    2006    2007    2008  \
# 行业
# 3D印刷       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 云计算      290.0   70.0  3500.0  150.0     NaN   70.0     NaN     NaN   290.0
# 人工智能       NaN    NaN     NaN  200.0   150.0  570.0   150.0    70.0     NaN
# 健康科技      70.0   70.0     NaN    NaN     NaN    NaN    70.0   220.0    70.0
# 共享经济       NaN    NaN     NaN    NaN     NaN    NaN   150.0     NaN  2700.0
# 区块链        NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 即时通讯       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 大数据        NaN   70.0     NaN    NaN  1250.0    NaN     NaN     NaN   140.0
# 媒体和娱乐      NaN    NaN     NaN  270.0     NaN  200.0   570.0  1000.0     NaN
# 房地产科技      NaN    NaN   200.0    NaN     NaN    NaN     NaN     NaN     NaN
# 教育科技       NaN   70.0     NaN    NaN     NaN    NaN   100.0   140.0   470.0
# 新能源        NaN    NaN     NaN    NaN     NaN    NaN   140.0   140.0   140.0
# 新能源汽车      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 新零售        NaN    NaN    70.0    NaN     NaN    NaN    70.0    70.0     NaN
# 机器人        NaN    NaN     NaN    NaN     NaN    NaN  1000.0     NaN     NaN
# 消费品        NaN    NaN     NaN    NaN     NaN    NaN   150.0     NaN     NaN
# 游戏         NaN    NaN     NaN    NaN   400.0    NaN     NaN   350.0   350.0
# 物流       100.0    NaN     NaN    NaN     NaN    NaN     NaN  1000.0   300.0
# 生命科学     150.0    NaN     NaN    NaN     NaN  150.0   150.0    70.0   800.0
# 电子商务       NaN    NaN     NaN    NaN   350.0  270.0   150.0   210.0   540.0
# 网络安全       NaN    NaN     NaN    NaN     NaN    NaN     NaN   570.0     NaN
# 航天         NaN    NaN  2500.0    NaN     NaN    NaN    70.0     NaN     NaN
# 虚拟与增强现实    NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 软件与服务      NaN  100.0   150.0    NaN     NaN  100.0     NaN   210.0   100.0
# 金融科技     220.0    NaN   200.0    NaN     NaN  300.0   640.0   300.0   220.0
#
# 成立年份       2009    2010    2011    2012    2013     2014    2015    2016  \
# 行业
# 3D印刷        NaN     NaN    70.0     NaN   150.0      NaN   150.0     NaN
# 云计算       360.0   360.0   670.0   880.0   650.0    540.0   370.0     NaN
# 人工智能      320.0    70.0   440.0   360.0   440.0   1070.0   610.0  1310.0
# 健康科技      250.0   850.0   410.0   340.0   340.0      NaN   140.0   600.0
# 共享经济       70.0  3200.0   170.0  4600.0   420.0      NaN  1270.0   270.0
# 区块链         NaN     NaN    70.0   900.0  1300.0     70.0   150.0     NaN
# 即时通讯       70.0   150.0    70.0   220.0     NaN     70.0     NaN     NaN
# 大数据       100.0   140.0   210.0   370.0   200.0     70.0   170.0     NaN
# 媒体和娱乐     150.0     NaN  1350.0  5340.0   400.0    520.0   220.0     NaN
# 房地产科技       NaN   100.0   440.0   240.0    70.0      NaN   370.0     NaN
# 教育科技        NaN    70.0    70.0   270.0   270.0    340.0     NaN     NaN
# 新能源        70.0     NaN   220.0     NaN     NaN      NaN     NaN   150.0
# 新能源汽车     350.0     NaN     NaN     NaN     NaN   1070.0   520.0     NaN
# 新零售         NaN     NaN   220.0     NaN   220.0      NaN   140.0     NaN
# 机器人         NaN     NaN     NaN   300.0   100.0      NaN     NaN   200.0
# 消费品         NaN   150.0     NaN   370.0     NaN    140.0  3570.0    70.0
# 游戏          NaN     NaN     NaN   440.0     NaN      NaN   100.0     NaN
# 物流          NaN   370.0   740.0   770.0  2610.0   1180.0   360.0    70.0
# 生命科学      270.0   370.0    70.0   220.0    70.0    800.0   300.0   550.0
# 电子商务     1250.0  1750.0  1230.0  1900.0   170.0   1700.0   580.0   140.0
# 网络安全       70.0    70.0     NaN     NaN    70.0      NaN   200.0     NaN
# 航天          NaN     NaN     NaN   200.0     NaN      NaN     NaN     NaN
# 虚拟与增强现实     NaN   300.0   400.0    70.0     NaN      NaN     NaN     NaN
# 软件与服务     140.0   150.0    70.0   320.0   340.0    360.0     NaN     NaN
# 金融科技      210.0  2520.0  4040.0   990.0  2910.0  11570.0  1290.0   210.0
#
# 成立年份      2017   2018   2019
# 行业
# 3D印刷       NaN    NaN    NaN
# 云计算        NaN    NaN    NaN
# 人工智能       NaN    NaN    NaN
# 健康科技     150.0   70.0  100.0
# 共享经济     370.0    NaN    NaN
# 区块链      300.0    NaN    NaN
# 即时通讯       NaN    NaN    NaN
# 大数据        NaN    NaN    NaN
# 媒体和娱乐      NaN    NaN    NaN
# 房地产科技      NaN  600.0    NaN
# 教育科技       NaN    NaN    NaN
# 新能源        NaN    NaN    NaN
# 新能源汽车    590.0    NaN    NaN
# 新零售       70.0   70.0    NaN
# 机器人        NaN    NaN    NaN
# 消费品      150.0  150.0    NaN
# 游戏         NaN    NaN    NaN
# 物流         NaN    NaN    NaN
# 生命科学       NaN    NaN    NaN
# 电子商务      70.0    NaN    NaN
# 网络安全       NaN    NaN   70.0
# 航天         NaN    NaN    NaN
# 虚拟与增强现实    NaN    NaN    NaN
# 软件与服务      NaN    NaN    NaN
# 金融科技     200.0  200.0    NaN

# %%
# 总值排序
排序 = 分进合击迸阶.sum(axis=1).sort_values(ascending=False).index
排序
排序_总值 = 分进合击迸阶.sum(axis=1).sort_values(ascending=False).values
排序_总值
分进合击迸阶_排序过 =  分进合击迸阶.loc[排序]
分进合击迸阶_排序过
分进合击迸阶_排序过['总值'] = 排序_总值
分进合击迸阶_排序过
# Out:
# 成立年份      2000   2001    2002   2003    2004   2005    2006    2007    2008  \
# 行业
# 金融科技     220.0    NaN   200.0    NaN     NaN  300.0   640.0   300.0   220.0
# 共享经济       NaN    NaN     NaN    NaN     NaN    NaN   150.0     NaN  2700.0
# 电子商务       NaN    NaN     NaN    NaN   350.0  270.0   150.0   210.0   540.0
# 媒体和娱乐      NaN    NaN     NaN  270.0     NaN  200.0   570.0  1000.0     NaN
# 云计算      290.0   70.0  3500.0  150.0     NaN   70.0     NaN     NaN   290.0
# 物流       100.0    NaN     NaN    NaN     NaN    NaN     NaN  1000.0   300.0
# 人工智能       NaN    NaN     NaN  200.0   150.0  570.0   150.0    70.0     NaN
# 消费品        NaN    NaN     NaN    NaN     NaN    NaN   150.0     NaN     NaN
# 生命科学     150.0    NaN     NaN    NaN     NaN  150.0   150.0    70.0   800.0
# 健康科技      70.0   70.0     NaN    NaN     NaN    NaN    70.0   220.0    70.0
# 区块链        NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 航天         NaN    NaN  2500.0    NaN     NaN    NaN    70.0     NaN     NaN
# 大数据        NaN   70.0     NaN    NaN  1250.0    NaN     NaN     NaN   140.0
# 新能源汽车      NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 软件与服务      NaN  100.0   150.0    NaN     NaN  100.0     NaN   210.0   100.0
# 房地产科技      NaN    NaN   200.0    NaN     NaN    NaN     NaN     NaN     NaN
# 教育科技       NaN   70.0     NaN    NaN     NaN    NaN   100.0   140.0   470.0
# 游戏         NaN    NaN     NaN    NaN   400.0    NaN     NaN   350.0   350.0
# 机器人        NaN    NaN     NaN    NaN     NaN    NaN  1000.0     NaN     NaN
# 网络安全       NaN    NaN     NaN    NaN     NaN    NaN     NaN   570.0     NaN
# 新零售        NaN    NaN    70.0    NaN     NaN    NaN    70.0    70.0     NaN
# 新能源        NaN    NaN     NaN    NaN     NaN    NaN   140.0   140.0   140.0
# 虚拟与增强现实    NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 即时通讯       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 3D印刷       NaN    NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
#
# 成立年份       2009  ...    2011    2012    2013     2014    2015    2016   2017  \
# 行业               ...
# 金融科技      210.0  ...  4040.0   990.0  2910.0  11570.0  1290.0   210.0  200.0
# 共享经济       70.0  ...   170.0  4600.0   420.0      NaN  1270.0   270.0  370.0
# 电子商务     1250.0  ...  1230.0  1900.0   170.0   1700.0   580.0   140.0   70.0
# 媒体和娱乐     150.0  ...  1350.0  5340.0   400.0    520.0   220.0     NaN    NaN
# 云计算       360.0  ...   670.0   880.0   650.0    540.0   370.0     NaN    NaN
# 物流          NaN  ...   740.0   770.0  2610.0   1180.0   360.0    70.0    NaN
# 人工智能      320.0  ...   440.0   360.0   440.0   1070.0   610.0  1310.0    NaN
# 消费品         NaN  ...     NaN   370.0     NaN    140.0  3570.0    70.0  150.0
# 生命科学      270.0  ...    70.0   220.0    70.0    800.0   300.0   550.0    NaN
# 健康科技      250.0  ...   410.0   340.0   340.0      NaN   140.0   600.0  150.0
# 区块链         NaN  ...    70.0   900.0  1300.0     70.0   150.0     NaN  300.0
# 航天          NaN  ...     NaN   200.0     NaN      NaN     NaN     NaN    NaN
# 大数据       100.0  ...   210.0   370.0   200.0     70.0   170.0     NaN    NaN
# 新能源汽车     350.0  ...     NaN     NaN     NaN   1070.0   520.0     NaN  590.0
# 软件与服务     140.0  ...    70.0   320.0   340.0    360.0     NaN     NaN    NaN
# 房地产科技       NaN  ...   440.0   240.0    70.0      NaN   370.0     NaN    NaN
# 教育科技        NaN  ...    70.0   270.0   270.0    340.0     NaN     NaN    NaN
# 游戏          NaN  ...     NaN   440.0     NaN      NaN   100.0     NaN    NaN
# 机器人         NaN  ...     NaN   300.0   100.0      NaN     NaN   200.0    NaN
# 网络安全       70.0  ...     NaN     NaN    70.0      NaN   200.0     NaN    NaN
# 新零售         NaN  ...   220.0     NaN   220.0      NaN   140.0     NaN   70.0
# 新能源        70.0  ...   220.0     NaN     NaN      NaN     NaN   150.0    NaN
# 虚拟与增强现实     NaN  ...   400.0    70.0     NaN      NaN     NaN     NaN    NaN
# 即时通讯       70.0  ...    70.0   220.0     NaN     70.0     NaN     NaN    NaN
# 3D印刷        NaN  ...    70.0     NaN   150.0      NaN   150.0     NaN    NaN
#
# 成立年份      2018   2019       总值
# 行业
# 金融科技     200.0    NaN  26020.0
# 共享经济       NaN    NaN  13220.0
# 电子商务       NaN    NaN  10310.0
# 媒体和娱乐      NaN    NaN  10020.0
# 云计算        NaN    NaN   8200.0
# 物流         NaN    NaN   7500.0
# 人工智能       NaN    NaN   5760.0
# 消费品      150.0    NaN   4750.0
# 生命科学       NaN    NaN   3970.0
# 健康科技      70.0  100.0   3750.0
# 区块链        NaN    NaN   2790.0
# 航天         NaN    NaN   2770.0
# 大数据        NaN    NaN   2720.0
# 新能源汽车      NaN    NaN   2530.0
# 软件与服务      NaN    NaN   2040.0
# 房地产科技    600.0    NaN   2020.0
# 教育科技       NaN    NaN   1800.0
# 游戏         NaN    NaN   1640.0
# 机器人        NaN    NaN   1600.0
# 网络安全       NaN   70.0   1050.0
# 新零售       70.0    NaN    930.0
# 新能源        NaN    NaN    860.0
# 虚拟与增强现实    NaN    NaN    770.0
# 即时通讯       NaN    NaN    580.0
# 3D印刷       NaN    NaN    370.0
#
# [25 rows x 21 columns]

# %%
分进合击初阶 = df.groupby(by= ["行业", "成立年份"]) \
                .agg({"估值（亿人民币）":"sum"})
分进合击初阶
# Out:
#            估值（亿人民币）
# 行业   成立年份
# 3D印刷 2011        70
#      2013       150
#      2015       150
# 云计算  2000       290
#      2001        70
# ...             ...
# 金融科技 2014     11570
#      2015      1290
#      2016       210
#      2017       200
#      2018       200
#
# [212 rows x 1 columns]

# %%
分进合击初阶.reset_index()
# Out:
#        行业  成立年份  估值（亿人民币）
# 0    3D印刷  2011        70
# 1    3D印刷  2013       150
# 2    3D印刷  2015       150
# 3     云计算  2000       290
# 4     云计算  2001        70
# ..    ...   ...       ...
# 207  金融科技  2014     11570
# 208  金融科技  2015      1290
# 209  金融科技  2016       210
# 210  金融科技  2017       200
# 211  金融科技  2018       200
#
# [212 rows x 3 columns]

# %%
分进合击初阶_pivot = 分进合击初阶.reset_index().pivot(index = '成立年份',columns='行业' ,values='估值（亿人民币）' )
分进合击初阶_pivot
# Out:
# 行业     3D印刷     云计算    人工智能   健康科技    共享经济     区块链   即时通讯     大数据   媒体和娱乐  \
# 成立年份
# 2000    NaN   290.0     NaN   70.0     NaN     NaN    NaN     NaN     NaN
# 2001    NaN    70.0     NaN   70.0     NaN     NaN    NaN    70.0     NaN
# 2002    NaN  3500.0     NaN    NaN     NaN     NaN    NaN     NaN     NaN
# 2003    NaN   150.0   200.0    NaN     NaN     NaN    NaN     NaN   270.0
# 2004    NaN     NaN   150.0    NaN     NaN     NaN    NaN  1250.0     NaN
# 2005    NaN    70.0   570.0    NaN     NaN     NaN    NaN     NaN   200.0
# 2006    NaN     NaN   150.0   70.0   150.0     NaN    NaN     NaN   570.0
# 2007    NaN     NaN    70.0  220.0     NaN     NaN    NaN     NaN  1000.0
# 2008    NaN   290.0     NaN   70.0  2700.0     NaN    NaN   140.0     NaN
# 2009    NaN   360.0   320.0  250.0    70.0     NaN   70.0   100.0   150.0
# 2010    NaN   360.0    70.0  850.0  3200.0     NaN  150.0   140.0     NaN
# 2011   70.0   670.0   440.0  410.0   170.0    70.0   70.0   210.0  1350.0
# 2012    NaN   880.0   360.0  340.0  4600.0   900.0  220.0   370.0  5340.0
# 2013  150.0   650.0   440.0  340.0   420.0  1300.0    NaN   200.0   400.0
# 2014    NaN   540.0  1070.0    NaN     NaN    70.0   70.0    70.0   520.0
# 2015  150.0   370.0   610.0  140.0  1270.0   150.0    NaN   170.0   220.0
# 2016    NaN     NaN  1310.0  600.0   270.0     NaN    NaN     NaN     NaN
# 2017    NaN     NaN     NaN  150.0   370.0   300.0    NaN     NaN     NaN
# 2018    NaN     NaN     NaN   70.0     NaN     NaN    NaN     NaN     NaN
# 2019    NaN     NaN     NaN  100.0     NaN     NaN    NaN     NaN     NaN
#
# 行业    房地产科技  ...     消费品     游戏      物流   生命科学    电子商务   网络安全      航天  \
# 成立年份         ...
# 2000    NaN  ...     NaN    NaN   100.0  150.0     NaN    NaN     NaN
# 2001    NaN  ...     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 2002  200.0  ...     NaN    NaN     NaN    NaN     NaN    NaN  2500.0
# 2003    NaN  ...     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 2004    NaN  ...     NaN  400.0     NaN    NaN   350.0    NaN     NaN
# 2005    NaN  ...     NaN    NaN     NaN  150.0   270.0    NaN     NaN
# 2006    NaN  ...   150.0    NaN     NaN  150.0   150.0    NaN    70.0
# 2007    NaN  ...     NaN  350.0  1000.0   70.0   210.0  570.0     NaN
# 2008    NaN  ...     NaN  350.0   300.0  800.0   540.0    NaN     NaN
# 2009    NaN  ...     NaN    NaN     NaN  270.0  1250.0   70.0     NaN
# 2010  100.0  ...   150.0    NaN   370.0  370.0  1750.0   70.0     NaN
# 2011  440.0  ...     NaN    NaN   740.0   70.0  1230.0    NaN     NaN
# 2012  240.0  ...   370.0  440.0   770.0  220.0  1900.0    NaN   200.0
# 2013   70.0  ...     NaN    NaN  2610.0   70.0   170.0   70.0     NaN
# 2014    NaN  ...   140.0    NaN  1180.0  800.0  1700.0    NaN     NaN
# 2015  370.0  ...  3570.0  100.0   360.0  300.0   580.0  200.0     NaN
# 2016    NaN  ...    70.0    NaN    70.0  550.0   140.0    NaN     NaN
# 2017    NaN  ...   150.0    NaN     NaN    NaN    70.0    NaN     NaN
# 2018  600.0  ...   150.0    NaN     NaN    NaN     NaN    NaN     NaN
# 2019    NaN  ...     NaN    NaN     NaN    NaN     NaN   70.0     NaN
#
# 行业    虚拟与增强现实  软件与服务     金融科技
# 成立年份
# 2000      NaN    NaN    220.0
# 2001      NaN  100.0      NaN
# 2002      NaN  150.0    200.0
# 2003      NaN    NaN      NaN
# 2004      NaN    NaN      NaN
# 2005      NaN  100.0    300.0
# 2006      NaN    NaN    640.0
# 2007      NaN  210.0    300.0
# 2008      NaN  100.0    220.0
# 2009      NaN  140.0    210.0
# 2010    300.0  150.0   2520.0
# 2011    400.0   70.0   4040.0
# 2012     70.0  320.0    990.0
# 2013      NaN  340.0   2910.0
# 2014      NaN  360.0  11570.0
# 2015      NaN    NaN   1290.0
# 2016      NaN    NaN    210.0
# 2017      NaN    NaN    200.0
# 2018      NaN    NaN    200.0
# 2019      NaN    NaN      NaN
#
# [20 rows x 25 columns]

# %%
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['Songti SC']
分进合击初阶_pivot.plot(figsize=(16,10))
# Out:
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 25104 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 31435 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 25104 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 31435 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 34892 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 19994 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21360 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21047 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20113 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 35745 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 31639 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24037 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26234 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 33021 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20581 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24247 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 31185 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 25216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20849 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20139 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32463 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27982 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21306 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22359 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 38142 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21363 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26102 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36890 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 35759 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22823 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 25454 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23186 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20307 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21644 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23089 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20048 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 25151 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20135 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 25945 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32946 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 28304 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27773 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36710 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 38646 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21806 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26426 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22120 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 28040 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36153 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21697 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 28216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 25103 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27969 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29983 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23398 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 30005 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23376 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21830 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21153 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32593 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32476 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23433 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20840 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 33322 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22825 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 34394 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 25311 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 19982 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22686 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24378 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23454 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36719 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20214 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26381 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 37329 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 34701 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 34892 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 19994 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21360 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21047 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20113 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 35745 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 31639 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24037 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26234 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 33021 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20581 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24247 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 31185 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 25216 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20849 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20139 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32463 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27982 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21306 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22359 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 38142 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21363 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26102 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 36890 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 35759 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22823 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 25454 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23186 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20307 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21644 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23089 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20048 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 25151 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22320 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20135 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 25945 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32946 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 28304 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27773 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 36710 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 38646 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21806 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26426 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22120 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 28040 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 36153 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21697 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 28216 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 25103 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 29289 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27969 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 29983 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21629 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23398 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 30005 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23376 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21830 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21153 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32593 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32476 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23433 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20840 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 33322 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22825 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 34394 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 25311 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 19982 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22686 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24378 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 29616 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23454 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 36719 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20214 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26381 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 37329 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 34701 missing from current font.
#   font.set_text(s, 0, flags=flags)
