# %% [markdown]
# # 数据科学之分进合击进阶分析策略
#
# *  本周主要内容：时间 数据来源：[pandas空气质量处理时间](https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/09_timeseries.html) and 独角兽数据
# *  上周主要内容：空间
# *  20春_Web数据分析_week011
# *  电子讲义设计者：许智超，廖汉腾

# %%
# %%html
# <style>
# /* 本电子讲义使用之CSS */
# div.code_cell {
#     background-color: #e5f1fe;
# }
# div.cell.selected {
#     background-color: #effee2;
#     font-size: 2rem;
#     line-height: 2.4rem;
# }
# div.cell.selected .rendered_html table {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html pre code {
#     background-color: #C4E4ff;
#     padding: 2px 25px;
# }
# .rendered_html pre {
#     background-color: #99c9ff;
# }
# div.code_cell .CodeMirror {
#     font-size: 2rem !important;
#     line-height: 3.6rem !important;
# }
# .rendered_html img, .rendered_html svg {
#     max-width: 60%;
#     height: auto;
#     float: right;
# }
#
# .rendered_html img[src*="#full"], .rendered_html svg[src*="#full"] {
#     max-width: 100%;
#     height: auto;
#     float: none;
# }
#
# .rendered_html img[src*="#thumbnail"], .rendered_html svg[src*="#thumbnail"] {
#     max-width: 15%;
#     height: auto;
# }
# .rendered_html img[src*="#thumbnailauto"], .rendered_html svg[src*="#thumbnail"] {
#     max-width: auto;
#     height: auto;
# }
#
# /* Gradient transparent - color - transparent */
# hr {
#     border: 0;
#     border-bottom: 1px dashed #ccc;
# }
# .emoticon{
#     font-size: 5rem;
#     line-height: 4.4rem;
#     text-align: center;
#     vertical-align: middle;
# }
# .bg-reshape {
#     width: 550px;
#     height: 205px;
#     background: url('../20春_pandas_CheatSheet.svg') -205px -110px;
#     float: left;
# }
# .break {
#                    page-break-after: right;
#                    width:100%;
#                    clear:both;
# }
# </style>
# Out:
# <style>
# /* 本电子讲义使用之CSS */
# div.code_cell {
#     background-color: #e5f1fe;
# }
# div.cell.selected {
#     background-color: #effee2;
#     font-size: 2rem;
#     line-height: 2.4rem;
# }
# div.cell.selected .rendered_html table {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html pre code {
#     background-color: #C4E4ff;
#     padding: 2px 25px;
# }
# .rendered_html pre {
#     background-color: #99c9ff;
# }
# div.code_cell .CodeMirror {
#     font-size: 2rem !important;
#     line-height: 3.6rem !important;
# }
# .rendered_html img, .rendered_html svg {
#     max-width: 60%;
#     height: auto;
#     float: right;
# }
#
# .rendered_html img[src*="#full"], .rendered_html svg[src*="#full"] {
#     max-width: 100%;
#     height: auto;
#     float: none;
# }
#
# .rendered_html img[src*="#thumbnail"], .rendered_html svg[src*="#thumbnail"] {
#     max-width: 15%;
#     height: auto;
# }
# .rendered_html img[src*="#thumbnailauto"], .rendered_html svg[src*="#thumbnail"] {
#     max-width: auto;
#     height: auto;
# }
#
# /* Gradient transparent - color - transparent */
# hr {
#     border: 0;
#     border-bottom: 1px dashed #ccc;
# }
# .emoticon{
#     font-size: 5rem;
#     line-height: 4.4rem;
#     text-align: center;
#     vertical-align: middle;
# }
# .bg-reshape {
#     width: 550px;
#     height: 205px;
#     background: url('../20春_pandas_CheatSheet.svg') -205px -110px;
#     float: left;
# }
# .break {
#                    page-break-after: right;
#                    width:100%;
#                    clear:both;
# }
# </style>

# %% [markdown]
# ##  介绍
#
# ### 上周主要内容（时间）
#
# 1.  Pandas与时间相关的4个概念
#     1. 日期时间（Date times）
#     2. 时间增量（Time deltas）
#     3. 时间跨度（Time spans）
#     4. 日期偏移量（Date offsets）
# 2.  Pandas的datetime属性
#     1. to_datetime
#     2. Timestamp
# 2.  Pandas处理时间数据
#     1. 北京天气数据
#     2. 三个地区空气质量数据
#         * 日期的可比性
#         * 新增year，week，quarter列的时间数据
#         * 分进合击：以时间为分组操作计算mean丶max丶min等
#         * 时间重塑
#         * 计算时间段的变化
#         * 时间采样
#     3. 独角兽数据
#         * 每5年统计计算不同值的变化
# 3.  交互式可视化
#     1. 独角兽数据
#
# ### 本周内容概述（空间分析—图资）
#
# #### 基本概念
# * 空间分析仰赖图资
# * 有正确图资地名对映关系，才能做数据结合
# * 如全世界地图，必需将欲可视化的数据地名(或编码)，和图资地名(或编码)变成一致才行
#
# #### Pyecharts的好处
# * 中文, 百度
# * 动态地图 [交互式地理图表](https://pyecharts.org/#/zh-cn/geography_charts),3种API
#     * Geo：地理坐标系
#     * Map：地图
#     * Baidu: 百度地图
#
# #### Pyecharts的问题
# * 空间图资文档稀缺，仅有[地理地图数据](http://pyecharts.org/#/zh-cn/datasets)丶[资源引用](http://pyecharts.org/#/zh-cn/assets_host)
# * 空间图资文档不在主项目内，分散於[pyecharts-assets](https://github.com/pyecharts/pyecharts-assets)丶[geo-region-coords 中国五级行政区域坐标](https://github.com/pyecharts/geo-region-coords)，文档也缺
#
#
#
# ### 本电子讲义说明
#
# 本电子讲义为一系列课程的主要教材
# *  课程：20春_数据分析pandas （中山大学南方学院）
# *  设计者：廖汉腾, 许智超
# * 参考来源: [官方英文新手教程](https://pandas.pydata.org/pandas-docs/version/1.0.2/getting_started/index.html#getting-started)
#
# -----
#
# 课堂教学方式：
# * 分段式以英文新手教程的内容做示范及说明
# * 课堂上以实际中文数据做操练，每段约10-15分钟
# * 抽学生联mic自播说明难点及成果点，教师总结
#
# -----
#
# 课后实践方式：
# * 学生fork教师提供的代码，做以下实践
# * (必做)一项为此代码的实践，学生需要对ipynb文档中的说明(含markdown及图片)及代码进行演化改进，可以是注解说明，可以是调整参数实验，可以是额外方法实践，可以是以上的组合，学生
# * (选做)一项为此代码的延伸实践，学生对ipynb文档中的一部分或全部进行演化，变成另一个独立项目，说好或做好一件事

# %%
import datetime
import numpy as np
import pandas as pd

# %% [markdown]
# # pyecharts动态地图展示
#
# ## Map：地图

# %%
from pyecharts.charts import Map  # 注意这里与老版本pyecharts调用的区别
from pyecharts import options as opts
import random
country = ['China', 'Canada', 'France', 'Japan', 'Russia', 'USA']
data_world = [(i, random.randint(100, 200)) for i in country]
world = (
            Map()
            .add('', data_world, maptype="world" ) # # 数据, world_china_provinces
            .set_global_opts(
                title_opts=opts.TitleOpts(title='世界地图'),
                visualmap_opts=opts.VisualMapOpts(
                    max_=200,
                    min_=100,
                    is_piecewise=True)  # 定义图例为分段型，默认为连续的图例
            )
            .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
            .render(path='世界地图2.html')
)

# %% [markdown]
# ### 观察(A)欲可视化数据，及(B)可视化结果是否一致
# 观察一下，以上代码哪里数据出现错误，以地图没有呈现？
#
# ### 除错后的代码

# %%
## 该您了不一致，美国的数据既没有高亮也没有显示出来
from pyecharts.charts import Map  # 注意这里与老版本pyecharts调用的区别

from pyecharts import options as opts

import random

country = ['China', 'Canada', 'France', 'Japan', 'Russia', 'United States']

data_world = [(i, random.randint(100, 200)) for i in country]

world = (
    Map().add('', data_world, maptype="world")  # # 数据, world_china_provinces
    .set_global_opts(
        title_opts=opts.TitleOpts(title='世界地图'),
        visualmap_opts=opts.VisualMapOpts(
            max_=200, min_=100, is_piecewise=True)  # 定义图例为分段型，默认为连续的图例
    ).set_series_opts(label_opts=opts.LabelOpts(
        is_show=False)).render_notebook()  #path='世界地图.html'
)

# %% [markdown]
# ## Geo：地理坐标系

# %%
from pyecharts.charts import Geo
# from example.commons import Faker 此行可能因为代码迭代失效，改下句可行
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType
def geo_base() -> Geo:
    c = (
        Geo()
        .add_schema(maptype="china")
        .add("geo", [list(z) for z in zip(Faker.provinces, Faker.values())])
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            visualmap_opts=opts.VisualMapOpts(),
            title_opts=opts.TitleOpts(title="Geo-基本示例"),
        )
    )
    return c

# %%
地图示例 = geo_base()
地图示例.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="b289e4df89624f2fa6ceb8adb5c5fc10" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_b289e4df89624f2fa6ceb8adb5c5fc10 = echarts.init(
#                     document.getElementById('b289e4df89624f2fa6ceb8adb5c5fc10'), 'white', {renderer: 'canvas'});
#                 var option_b289e4df89624f2fa6ceb8adb5c5fc10 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         85
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         141
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         25
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         65
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         72
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         31
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         45
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "geo"
#             ],
#             "selected": {
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Geo-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_b289e4df89624f2fa6ceb8adb5c5fc10.setOption(option_b289e4df89624f2fa6ceb8adb5c5fc10);
#         });
#     </script>

# %%
print(Faker.values(),'\n',Faker.provinces)
# Out:
# [33, 65, 58, 53, 83, 124, 150]
#  ['广东', '北京', '上海', '江西', '湖南', '浙江', '江苏']

# %%
[list(z) for z in zip(Faker.provinces, Faker.values())]
# Out:
# [['广东', 149],
#  ['北京', 76],
#  ['上海', 42],
#  ['江西', 38],
#  ['湖南', 63],
#  ['浙江', 111],
#  ['江苏', 39]]

# %% [markdown]
# # 独角兽数据
#
# ## 导入

# %%
# A-0-0 简化栏位变数名称
df = pd.read_csv ("20春_pandas_week02_hurun_unicorn.tsv", encoding = "utf8", sep="\t")
df.columns = [x.replace('（亿人民币）','').replace('掌门人/','')\
               .replace('Company Name','独角兽_英')\
               .replace('企业名称','独角兽')\
               .replace('成立年份','成立年')\
               .replace('部分投资机构','投资机构')\
                for x in df.columns]
独角兽=df.copy()
独角兽.columns.name = "独角兽"
独角兽.head()# A-0-0 简化栏位变数名称

独角兽.head()
# Out:
# 独角兽  排名        独角兽          独角兽_英     估值  国家   城市     行业  \
# 0     1       蚂蚁金服  Ant Financial  10000  中国   杭州   金融科技
# 1     2       字节跳动      Bytedance   5000  中国   北京  媒体和娱乐
# 2     3       滴滴出行   Didi Chuxing   3600  中国   北京   共享经济
# 3     4      Infor          Infor   3500  美国   纽约    云计算
# 4     5  JUUL Labs      JUUL Labs   3400  美国  旧金山    消费品
#
# 独角兽                                                创始人   成立年  \
# 0                                                  井贤栋  2014
# 1                                                  张一鸣  2012
# 2                                                   程维  2012
# 3                                          Jim Schaper  2002
# 4    Adam Bowen, James Monsees, Kevin Burns, Tim Da...  2015
#
# 独角兽                                               投资机构
# 0                                       春华资本、中投海外、红杉资本
# 1                                  红杉资本、海纳亚洲、纪源资本、启明创投
# 2                               腾讯、阿里巴巴、红杉资本、经纬中国、纪源资本
# 3         Golden Gate Capital, Koch Equity Development
# 4    M13, Timothy Davis, Evolution VC Partners, Tig...

# %% [markdown]
# ## 国家地区

# %%
独角兽_国家地区 =  独角兽.groupby("国家").agg({"独角兽":"count","估值":"sum"}).rename(columns={"独角兽":"数量"})
独角兽_国家地区.数量.to_dict() #.index
# Out:
# {'中国': 206,
#  '以色列': 7,
#  '卢森堡': 1,
#  '印度': 21,
#  '印度尼西亚': 4,
#  '哥伦比亚': 1,
#  '巴西': 4,
#  '德国': 7,
#  '新加坡': 2,
#  '日本': 2,
#  '法国': 4,
#  '澳大利亚': 1,
#  '爱尔兰': 1,
#  '爱沙尼亚': 1,
#  '瑞典': 2,
#  '瑞士': 3,
#  '美国': 203,
#  '芬兰': 1,
#  '英国': 13,
#  '菲律宾': 1,
#  '西班牙': 1,
#  '阿根廷': 1,
#  '韩国': 6,
#  '马耳他': 1}

# %%
country = 独角兽_国家地区.index
data_world = [(k, v) for k, v in 独角兽_国家地区.数量.to_dict().items()]  
world = (
            Map()
            .add('', data_world, maptype="world" ) # # 数据, world_china_provinces
            .set_global_opts(
                title_opts=opts.TitleOpts(title='世界地图'),
                visualmap_opts=opts.VisualMapOpts(
                    max_=200,
                    min_=100,
                    is_piecewise=True)  # 定义图例为分段型，默认为连续的图例
            )
            .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
            .render(path='世界地图_独角兽.html')
)

# %%
data_world
# Out:
# [('中国', 206),
#  ('以色列', 7),
#  ('卢森堡', 1),
#  ('印度', 21),
#  ('印度尼西亚', 4),
#  ('哥伦比亚', 1),
#  ('巴西', 4),
#  ('德国', 7),
#  ('新加坡', 2),
#  ('日本', 2),
#  ('法国', 4),
#  ('澳大利亚', 1),
#  ('爱尔兰', 1),
#  ('爱沙尼亚', 1),
#  ('瑞典', 2),
#  ('瑞士', 3),
#  ('美国', 203),
#  ('芬兰', 1),
#  ('英国', 13),
#  ('菲律宾', 1),
#  ('西班牙', 1),
#  ('阿根廷', 1),
#  ('韩国', 6),
#  ('马耳他', 1)]

# %% [markdown]
# ## 为什麽做不出来?
# 怎麼解決呢？
#
# 提示：[国家地区名称搭桥表.xlsx](国家地区名称搭桥表.xlsx)

# %% [markdown]
# # 课堂实践

# %%
国家 = "中国"
按城市 = df.query('国家=="{c}"'.format(c=国家))
按城市
# Out:
#       排名    独角兽          独角兽_英     估值  国家  城市     行业  创始人   成立年  \
# 0      1   蚂蚁金服  Ant Financial  10000  中国  杭州   金融科技  井贤栋  2014
# 1      2   字节跳动      Bytedance   5000  中国  北京  媒体和娱乐  张一鸣  2012
# 2      3   滴滴出行   Didi Chuxing   3600  中国  北京   共享经济   程维  2012
# 6      6    陆金所          Lufax   2700  中国  上海   金融科技  计葵生  2011
# 10    11   微众银行         WeBank   1500  中国  深圳   金融科技   顾敏  2014
# ..   ...    ...            ...    ...  ..  ..    ...  ...   ...
# 486  264    有利网          Yooli     70  中国  北京   金融科技  吴逸然  2012
# 487  264   网易有道         Youdao     70  中国  北京  软件与服务   周枫  2007
# 488  264   云鸟科技        Yunniao     70  中国  北京     物流   韩毅  2014
# 490  264  掌门1对1       Zhangmen     70  中国  上海   教育科技   张翼  2014
# 491  264     转转     Zhuanzhuan     70  中国  北京   电子商务  姚劲波  2015
#
#                        投资机构
# 0            春华资本、中投海外、红杉资本
# 1       红杉资本、海纳亚洲、纪源资本、启明创投
# 2    腾讯、阿里巴巴、红杉资本、经纬中国、纪源资本
# 6       摩根士丹利、中银集团、国泰君安（香港）
# 10              腾讯、华平投资、淡马锡
# ..                      ...
# 486          高瓴资本、晨兴资本、软银中国
# 487               君联资本、慕华投资
# 488          华平投资、红杉资本、经纬中国
# 490          顺为资本、达晨创投、华平投资
# 491                      腾讯
#
# [206 rows x 10 columns]

# %%
城市_数值 = 按城市.groupby(["国家","城市"]).agg({"独角兽":"count","估值":"sum"})\
                  .rename(columns={"独角兽":"独角兽数量"})\
                  .reset_index()
城市_数值
# Out:
#     国家   城市  独角兽数量     估值
# 0   中国   上海     47   8990
# 1   中国   北京     81  22130
# 2   中国   南京     11   1550
# 3   中国   台北      1     70
# 4   中国   天津      3   1100
# 5   中国   广州      8   1000
# 6   中国  张家口      1    100
# 7   中国   成都      4    390
# 8   中国   无锡      1     70
# 9   中国   杭州     19  13290
# 10  中国   桐乡      1     70
# 11  中国   武汉      1    200
# 12  中国   深圳     17   4440
# 13  中国   绍兴      1    100
# 14  中国   贵阳      1    400
# 15  中国   重庆      2    170
# 16  中国   金华      1     70
# 17  中国   青岛      1    100
# 18  中国   香港      5    460

# %%
城市 = 城市_数值["城市"].to_list()
估值 = 城市_数值["估值"].to_list()

# %%
城市
# Out:
# ['上海',
#  '北京',
#  '南京',
#  '台北',
#  '天津',
#  '广州',
#  '张家口',
#  '成都',
#  '无锡',
#  '杭州',
#  '桐乡',
#  '武汉',
#  '深圳',
#  '绍兴',
#  '贵阳',
#  '重庆',
#  '金华',
#  '青岛',
#  '香港']

# %%
估值
# Out:
# [8990,
#  22130,
#  1550,
#  70,
#  1100,
#  1000,
#  100,
#  390,
#  70,
#  13290,
#  70,
#  200,
#  4440,
#  100,
#  400,
#  170,
#  70,
#  100,
#  460]

# %%
[list(z) for z in zip(城市,估值)]
# Out:
# [['上海', 8990],
#  ['北京', 22130],
#  ['南京', 1550],
#  ['台北', 70],
#  ['天津', 1100],
#  ['广州', 1000],
#  ['张家口', 100],
#  ['成都', 390],
#  ['无锡', 70],
#  ['杭州', 13290],
#  ['桐乡', 70],
#  ['武汉', 200],
#  ['深圳', 4440],
#  ['绍兴', 100],
#  ['贵阳', 400],
#  ['重庆', 170],
#  ['金华', 70],
#  ['青岛', 100],
#  ['香港', 460]]

# %%
from pyecharts.charts import Geo
# from example.commons import Faker 此行可能因为代码迭代失效，改下句可行
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType
def geo_base() -> Geo:
    c = (
        Geo()
        .add_schema(maptype="china")
        .add("geo", [list(z) for z in zip(城市,估值)])
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            visualmap_opts=opts.VisualMapOpts(),
            title_opts=opts.TitleOpts(title="Geo-基本示例"),
        )
    )
    return c

# %%
地图示例 = geo_base()
地图示例.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="8152924e6f9a41f6a54b3eeec5e01b40" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_8152924e6f9a41f6a54b3eeec5e01b40 = echarts.init(
#                     document.getElementById('8152924e6f9a41f6a54b3eeec5e01b40'), 'white', {renderer: 'canvas'});
#                 var option_8152924e6f9a41f6a54b3eeec5e01b40 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         8990
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         22130
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         1550
#                     ]
#                 },
#                 {
#                     "name": "\u53f0\u5317",
#                     "value": [
#                         121.3,
#                         25.03,
#                         70
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.200983,
#                         39.084158,
#                         1100
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         1000
#                     ]
#                 },
#                 {
#                     "name": "\u5f20\u5bb6\u53e3",
#                     "value": [
#                         114.87,
#                         40.82,
#                         100
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         390
#                     ]
#                 },
#                 {
#                     "name": "\u65e0\u9521",
#                     "value": [
#                         120.29,
#                         31.59,
#                         70
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         13290
#                     ]
#                 },
#                 {
#                     "name": "\u6850\u4e61",
#                     "value": [
#                         120.32,
#                         30.38,
#                         70
#                     ]
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": [
#                         114.31,
#                         30.52,
#                         200
#                     ]
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": [
#                         114.07,
#                         22.62,
#                         4440
#                     ]
#                 },
#                 {
#                     "name": "\u7ecd\u5174",
#                     "value": [
#                         120.58,
#                         30.01,
#                         100
#                     ]
#                 },
#                 {
#                     "name": "\u8d35\u9633",
#                     "value": [
#                         106.71,
#                         26.57,
#                         400
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         170
#                     ]
#                 },
#                 {
#                     "name": "\u91d1\u534e",
#                     "value": [
#                         119.64,
#                         29.12,
#                         70
#                     ]
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": [
#                         120.33,
#                         36.07,
#                         100
#                     ]
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": [
#                         114.173355,
#                         22.320048,
#                         460
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "geo"
#             ],
#             "selected": {
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Geo-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_8152924e6f9a41f6a54b3eeec5e01b40.setOption(option_8152924e6f9a41f6a54b3eeec5e01b40);
#         });
#     </script>
